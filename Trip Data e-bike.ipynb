# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import folium

sns.set_theme()

# %%
df = pd.read_csv('C:\\Asus WebStorage\\psabin@gmail.com\\MySyncFolder\\Data Science Course\\Used CSVs\\CSB_2021-2023_All.csv')
display(df.head())
# Out:
# C:\Users\psabi\AppData\Local\Temp\ipykernel_13028\999932228.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Asus WebStorage\\psabin@gmail.com\\MySyncFolder\\Data Science Course\\Used CSVs\\CSB_2021-2023_All.csv')
#             ride_id  rideable_type           started_at             ended_at  \
# 0  5CB9DFCECF79AF84   classic_bike  2021-01-01 00:08:33  2021-01-01 00:33:53
# 1  629E059504606547  electric_bike  2021-01-01 00:13:43  2021-01-01 00:29:34
# 2  E74069873161EE33  electric_bike  2021-01-01 00:14:32  2021-01-01 00:28:45
# 3  91F95E512CABC46A   classic_bike  2021-01-01 00:15:45  2021-01-01 00:21:20
# 4  DA46A05139C0EA2F   classic_bike  2021-01-01 00:17:46  2021-01-01 00:21:00
#
#               start_station_name start_station_id  \
# 0          Maine Ave & 9th St SW          31646.0
# 1                 10th & U St NW          31111.0
# 2          17th & Corcoran St NW          31214.0
# 3  Wilson Blvd. & N. Vermont St.          31926.0
# 4              11th & Park Rd NW          31651.0
#
#                            end_station_name end_station_id  start_lat  \
# 0  Rosslyn Metro / Wilson Blvd & Ft Myer Dr        31015.0  38.880440
# 1                                       NaN            NaN  38.917193
# 2                      14th & Belmont St NW        31119.0  38.912138
# 3             Wilson Blvd. & N. Vermont St.        31926.0  38.879477
# 4                       14th & Newton St NW        31649.0  38.931322
#
#    start_lng    end_lat    end_lng member_casual
# 0 -77.025236  38.894600 -77.072305        member
# 1 -77.025894  38.960000 -77.020000        casual
# 2 -77.038568  38.920870 -77.031691        member
# 3 -77.114563  38.879477 -77.114563        member
# 4 -77.028247  38.931991 -77.032956        member

# %%
df['started_at'] = pd.to_datetime(df['started_at'])
df['ended_at'] = pd.to_datetime(df['ended_at'])
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8180626 entries, 0 to 8180625
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 811.4+ MB
# None

# %%
display(df['rideable_type'].value_counts())
# Out:
# rideable_type
# classic_bike     6157609
# electric_bike    1521056
# docked_bike       501961
# Name: count, dtype: int64

# %%
docked_bike_mask = df['rideable_type'] == 'docked_bike'

# %%
display(df.sample(5))
# Out:
#                   ride_id rideable_type          started_at  \
# 2042042  9925D1128155CB5A  classic_bike 2021-10-05 17:21:34
# 512644   36A9049D27FEF783   docked_bike 2021-04-23 15:51:36
# 3390469  391086EAA6EBDAF2  classic_bike 2022-04-13 21:01:47
# 6111988  5AD009E9F9AE65FF   docked_bike 2022-12-08 20:09:14
# 3692405  CFDA0A41FCFE9DB6  classic_bike 2022-05-13 07:41:32
#
#                    ended_at                 start_station_name  \
# 2042042 2021-10-05 17:25:20  Convention Center / 7th & M St NW
# 512644  2021-04-23 17:21:15                      3rd & M St NE
# 3390469 2022-04-13 22:13:43          Jefferson Dr & 14th St SW
# 6111988 2022-12-08 20:22:25         North Capitol St & G Pl NE
# 3692405 2022-05-13 07:49:53                      1st & M St NE
#
#         start_station_id                                   end_station_name  \
# 2042042          31223.0                 New Jersey Ave & N St NW/Dunbar HS
# 512644           31627.0                                      3rd & M St NE
# 3390469          31247.0  Smithsonian-National Mall / Jefferson Dr & 12t...
# 6111988          31637.0                                Rosedale Rec Center
# 3692405          31603.0                                      1st & O St NW
#
#         end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 2042042        31636.0  38.905737 -77.022270  38.907333 -77.015360
# 512644         31627.0  38.905470 -77.002130  38.905470 -77.002130
# 3390469        31248.0  38.888553 -77.032427  38.888774 -77.028694
# 6111988        31658.0  38.899703 -77.008911  38.897808 -76.979634
# 3692405        31519.0  38.905697 -77.005483  38.908643 -77.012365
#
#         member_casual
# 2042042        member
# 512644         casual
# 3390469        casual
# 6111988        casual
# 3692405        member

# %%
display(df[docked_bike_mask]['member_casual'].value_counts())
# Out:
# member_casual
# casual    501957
# member         4
# Name: count, dtype: int64

# %%
electric_mask = df['rideable_type'] == 'electric_bike'
electric = df[electric_mask].copy()
display(electric.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1521056 entries, 1 to 8180624
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   ride_id             1521056 non-null  object
#  1   rideable_type       1521056 non-null  object
#  2   started_at          1521056 non-null  datetime64[ns]
#  3   ended_at            1521056 non-null  datetime64[ns]
#  4   start_station_name  1052346 non-null  object
#  5   start_station_id    1052346 non-null  object
#  6   end_station_name    1021603 non-null  object
#  7   end_station_id      1021603 non-null  object
#  8   start_lat           1521056 non-null  float64
#  9   start_lng           1521056 non-null  float64
#  10  end_lat             1521056 non-null  float64
#  11  end_lng             1521056 non-null  float64
#  12  member_casual       1521056 non-null  object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 162.5+ MB
# None

# %%
electric.drop(['rideable_type'], axis=1, inplace=True)
display(electric.head())
# Out:
#              ride_id          started_at            ended_at  \
# 1   629E059504606547 2021-01-01 00:13:43 2021-01-01 00:29:34
# 2   E74069873161EE33 2021-01-01 00:14:32 2021-01-01 00:28:45
# 5   0FD3B4B2152425C3 2021-01-01 00:18:16 2021-01-01 00:29:05
# 7   78894BDABD9F21DD 2021-01-01 00:20:40 2021-01-01 00:35:36
# 17  3F8AFD9540FF8EDB 2021-01-01 00:26:41 2021-01-01 00:30:09
#
#               start_station_name start_station_id  \
# 1                 10th & U St NW          31111.0
# 2          17th & Corcoran St NW          31214.0
# 5                            NaN              NaN
# 7   Columbia Rd & Georgia Ave NW          31115.0
# 17          14th & Harvard St NW          31105.0
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 1                           NaN            NaN  38.917193 -77.025894
# 2          14th & Belmont St NW        31119.0  38.912138 -77.038568
# 5   Georgia Ave & Kennedy St NW        31415.0  38.930000 -77.030000
# 7                           NaN            NaN  38.928081 -77.023768
# 17                          NaN            NaN  38.926715 -77.032145
#
#       end_lat    end_lng member_casual
# 1   38.960000 -77.020000        casual
# 2   38.920870 -77.031691        member
# 5   38.956738 -77.027940        casual
# 7   38.900000 -77.020000        casual
# 17  38.930000 -77.040000        member

# %%
display(electric.tail())
# Out:
#                   ride_id          started_at            ended_at  \
# 8180617  4D371A6AF5E76AF1 2023-06-30 23:56:40 2023-07-01 00:03:58
# 8180619  5BC09D5C797C1608 2023-06-30 23:56:52 2023-07-01 00:00:03
# 8180620  BA67AE126D50EE25 2023-06-30 23:57:29 2023-07-01 00:00:07
# 8180621  E802A8D89245438B 2023-06-30 23:57:43 2023-07-01 00:07:16
# 8180624  5EAFC4B8F3E7680E 2023-06-30 23:59:01 2023-07-01 00:06:37
#
#                      start_station_name start_station_id     end_station_name  \
# 8180617  California St & Florida Ave NW          31116.0                  NaN
# 8180619       1st & Rhode Island Ave NW          31506.0        4th & W St NE
# 8180620                             NaN              NaN                  NaN
# 8180621                             NaN              NaN  14th & Newton St NW
# 8180624     Adams Mill & Columbia Rd NW          31104.0                  NaN
#
#         end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 8180617            NaN  38.917730 -77.040680  38.940000 -77.040000
# 8180619        31500.0  38.915345 -77.012277  38.919077 -77.000648
# 8180620            NaN  38.960000 -77.000000  38.960000 -77.000000
# 8180621        31649.0  38.910000 -77.030000  38.931991 -77.032956
# 8180624            NaN  38.923005 -77.042420  38.930000 -77.030000
#
#         member_casual
# 8180617        member
# 8180619        member
# 8180620        member
# 8180621        member
# 8180624        member

# %%
electric['weekend'] = electric['started_at'].dt.dayofweek >= 5

# %%
# Assuming 'start_time' is your datetime column:
electric['morning'] = electric['started_at'].dt.hour.between(1, 13)

# %%
display(electric.sample(20))
# Out:
#                   ride_id          started_at            ended_at  \
# 8156475  3E37C3FCBF1E6D76 2023-06-29 09:34:08 2023-06-29 09:46:21
# 7381959  2997CC2EC3FF6C0B 2023-05-06 10:17:10 2023-05-06 10:23:37
# 2772124  468CDCE53A826089 2022-01-09 00:51:59 2022-01-09 01:09:13
# 1160054  9EC0D2A1578F5A80 2021-07-06 18:32:29 2021-07-06 18:47:40
# 5223730  FE30ACB87DB149E9 2022-09-13 15:38:42 2022-09-13 16:04:37
# 8096095  501C12E9AA395BBE 2023-06-24 23:25:40 2023-06-24 23:30:44
# 266560   75E7E1A45BFB1F80 2021-03-19 17:48:27 2021-03-19 17:52:37
# 3351143  3E0CA0ED9EF661B3 2022-04-10 10:06:33 2022-04-10 10:07:56
# 6363881  3980D686F596E399 2023-01-21 12:33:06 2023-01-21 12:49:24
# 3447632  1B2828B210C190C2 2022-04-19 16:49:54 2022-04-19 16:54:27
# 2433659  7A390250DA7352D5 2021-11-12 23:21:09 2021-11-12 23:31:24
# 7137894  B98BD5EC519D66D5 2023-04-16 12:54:53 2023-04-16 13:23:39
# 6959211  399E36DCDF71A724 2023-04-03 15:56:18 2023-04-03 16:13:44
# 3927947  B2F46AB8D7D9D1A8 2022-06-02 16:00:47 2022-06-02 16:26:51
# 5366503  80EE4ACF177F33DA 2022-09-23 17:31:23 2022-09-23 17:34:30
# 7052566  20602529AF2D8A97 2023-04-10 17:29:06 2023-04-10 17:33:43
# 5460657  B8D380451F416CA0 2022-10-01 13:24:37 2022-10-01 13:36:58
# 2872299  9FD6E71B13D208EB 2022-02-03 17:39:14 2022-02-03 18:10:48
# 1392692  BF932917CE2F1B3D 2021-07-30 19:03:55 2021-07-30 19:08:18
# 8075691  0156F6F951680948 2023-06-23 17:15:21 2023-06-23 17:25:47
#
#                                    start_station_name start_station_id  \
# 8156475                                           NaN              NaN
# 7381959                          14th & Harvard St NW          31105.0
# 2772124                     1st & Rhode Island Ave NW          31506.0
# 1160054                         2nd St & Seaton Pl NE          31522.0
# 5223730                                           NaN              NaN
# 8096095                               3rd & Elm St NW          31118.0
# 266560   Tenleytown / Wisconsin Ave & Albemarle St NW          31303.0
# 3351143                        4th St & Madison Dr NW          31288.0
# 6363881                       6th St & Indiana Ave NW          31264.0
# 3447632                     King Greenleaf Rec Center          31654.0
# 2433659                   18th & New Hampshire Ave NW          31324.0
# 7137894                                           NaN              NaN
# 6959211                     1st & Rhode Island Ave NW          31506.0
# 3927947                           14th & Irving St NW          31124.0
# 5366503                                           NaN              NaN
# 7052566                           14th & Irving St NW          31124.0
# 5460657                                14th & V St NW          31101.0
# 2872299                           16th & Irving St NW          31122.0
# 1392692                           Eads St & 12th St S          31071.0
# 8075691                                 6th & K St NE          31645.0
#
#                                           end_station_name end_station_id  \
# 8156475                                        Tanner Park        31533.0
# 7381959                         Calvert St & Woodley Pl NW        31121.0
# 2772124                                      3rd & M st SE        31669.0
# 1160054                                      3rd & G St SE        31625.0
# 5223730                                                NaN            NaN
# 8096095                                Edgewood Rec Center        31529.0
# 266560                                 39th & Veazey St NW        31308.0
# 3351143                             4th St & Madison Dr NW        31288.0
# 6363881                                                NaN            NaN
# 3447632                                      4th & E St SW        31244.0
# 2433659                     California St & Florida Ave NW        31116.0
# 7137894                                      1st & M St NE        31603.0
# 6959211                                                NaN            NaN
# 3927947                            Lamont & Mt Pleasant NW        31107.0
# 5366503                                                NaN            NaN
# 7052566                                14th & Girard St NW        31123.0
# 5460657                                  Potomac & M St NW        31295.0
# 2872299                                                NaN            NaN
# 1392692                             Crystal Dr & 15th St S        31003.0
# 8075691  Eastern Market Metro / Pennsylvania Ave & 8th ...        31613.0
#
#          start_lat  start_lng    end_lat    end_lng member_casual  weekend  \
# 8156475  38.910000 -77.040000  38.911214 -77.002257        casual    False
# 7381959  38.926767 -77.032204  38.923583 -77.050046        member     True
# 2772124  38.915352 -77.012131  38.876823 -77.002161        member     True
# 1160054  38.914733 -77.003568  38.881273 -77.001811        casual    False
# 5223730  38.920000 -77.070000  38.930000 -77.030000        member    False
# 8096095  38.917618 -77.015939  38.924144 -77.002098        member     True
# 266560   38.947584 -77.079303  38.943851 -77.077079        casual    False
# 3351143  38.890496 -77.017335  38.890496 -77.017246        casual     True
# 6363881  38.894525 -77.019800  38.900000 -77.030000        member     True
# 3447632  38.876188 -77.012305  38.884120 -77.017445        member    False
# 2433659  38.911235 -77.041849  38.917738 -77.040758        member    False
# 7137894  38.930000 -77.070000  38.905697 -77.005483        member     True
# 6959211  38.915357 -77.012305  38.930000 -77.030000        member    False
# 3927947  38.928845 -77.032368  38.931900 -77.038800        member    False
# 5366503  38.930000 -77.030000  38.930000 -77.040000        casual    False
# 7052566  38.928580 -77.032247  38.925284 -77.032375        casual    False
# 5460657  38.917690 -77.031814  38.905509 -77.065246        member     True
# 2872299  38.928840 -77.036190  38.920000 -77.040000        member    False
# 1392692  38.862707 -77.054345  38.861073 -77.049558        casual    False
# 8075691  38.903158 -76.998460  38.884095 -76.995234        member    False
#
#          morning
# 8156475     True
# 7381959     True
# 2772124    False
# 1160054    False
# 5223730    False
# 8096095    False
# 266560     False
# 3351143     True
# 6363881     True
# 3447632    False
# 2433659    False
# 7137894     True
# 6959211    False
# 3927947    False
# 5366503    False
# 7052566    False
# 5460657     True
# 2872299    False
# 1392692    False
# 8075691    False

# %%
endstation_value_counts = electric['end_station_name'].value_counts()
display(endstation_value_counts.head(50))
# Out:
# end_station_name
# 14th & Irving St NW                                    10629
# Adams Mill & Columbia Rd NW                             9776
# Lamont & Mt Pleasant NW                                 9529
# 1st & M St NE                                           9436
# 15th & P St NW                                          8568
# New Hampshire Ave & T St NW                             8412
# Columbia & Ontario Rd NW                                8394
# Columbus Circle / Union Station                         8138
# 18th St & Wyoming Ave NW                                7991
# 14th & V St NW                                          7719
# Eastern Market Metro / Pennsylvania Ave & 8th St SE     7420
# 37th & O St NW / Georgetown University                  7245
# 14th St & Spring Rd NW                                  7219
# 14th & R St NW                                          7181
# Massachusetts Ave & Dupont Circle NW                    7146
# 8th & O St NW                                           6839
# 14th & Belmont St NW                                    6585
# 5th & K St NW                                           6522
# Reservoir Rd & 38th St NW                               6319
# 11th & Girard St NW                                     6142
# 6th & H St NE                                           6091
# 11th & Kenyon St NW                                     6053
# 11th & M St NW                                          6035
# Park Rd & Holmead Pl NW                                 6001
# 15th & W St NW                                          5891
# 14th & Rhode Island Ave NW                              5818
# 11th & Park Rd NW                                       5813
# Georgia & New Hampshire Ave NW                          5630
# 1st & Rhode Island Ave NW                               5604
# Columbia Rd & Belmont St NW                             5593
# 14th & Newton St NW                                     5261
# 3rd & M St NE                                           5247
# 23rd & M St NW                                          5192
# 17th & Corcoran St NW                                   5159
# California St & Florida Ave NW                          5147
# 14th & Otis Pl NW                                       5146
# Eckington Pl & Q St NE                                  5133
# Georgia Ave & Morton St NW                              5023
# 15th & Euclid St NW                                     5010
# Columbia Rd & Georgia Ave NW                            4917
# 4th & M St SW                                           4849
# 8th & H St NW                                           4800
# 20th & Columbia Rd NW                                   4796
# New Hampshire Ave & Ward Pl NW                          4771
# 4th & Florida Ave NE                                    4721
# Maine Ave & 9th St SW                                   4676
# 16th & Irving St NW                                     4562
# 7th & F St NW / National Portrait Gallery               4552
# 13th & U St NW                                          4534
# 3rd & H St NE                                           4520
# Name: count, dtype: int64

# %%
# Count the start stations
startstation_value_counts = electric['start_station_name'].value_counts()

# Count the end stations (already done in your case)
# endstation_value_counts = electric['end_station_name'].value_counts()

# Calculate the net total for each station
# Subtracting the Series will align on the index automatically
net_total = startstation_value_counts.subtract(endstation_value_counts, fill_value=0)

# net_total now contains the net total for each station.
# If a station name doesn't exist in one of the Series, it assumes a count of 0 for subtraction
display(net_total.head(20))
# Out:
# 10th & E St NW                                 9.0
# 10th & Florida Ave NW                         70.0
# 10th & G St NW                                20.0
# 10th & H St NE                                10.0
# 10th & K St NW                                54.0
# 10th & Monroe St NE                           73.0
# 10th & Quincy St NE / Turkey Thicket Rec       3.0
# 10th & Rhode Island Ave NE                     1.0
# 10th & U St NW                                38.0
# 10th St & Constitution Ave NW                 33.0
# 10th St & Florida Ave NW                       6.0
# 10th St & L'Enfant Plaza SW                   62.0
# 10th St & Rhode Island Ave NE                 10.0
# 10th St & Spring Rd NW                        39.0
# 11th & C St SE                                 8.0
# 11th & Clifton St NW                          76.0
# 11th & F St NW                                19.0
# 11th & Girard St NW                          397.0
# 11th & H St NE                                11.0
# 11th & Kenyon St NW                         1059.0
# Name: count, dtype: float64

# %%
# Convert the net_total Series to a DataFrame and name the column 'net_total'
stations = net_total.to_frame(name='net_total')

# Transform station names from the index to a column
stations.reset_index(inplace=True)

# Rename the 'index' column to 'station_name' for clarity
stations.rename(columns={'index': 'station_name'}, inplace=True)

# %%
# Drop duplicates to ensure one-to-one mapping for the merge
unique_stations = electric[['start_station_name', 'start_station_id', 'start_lat', 'start_lng']].drop_duplicates('start_station_name')

# Merge the unique stations with the 'stations' DataFrame based on the station name
stations = stations.merge(unique_stations, left_on='station_name', right_on='start_station_name', how='left')

# Now 'stations' has the additional columns merged based on matching station names
# Optionally, if you don't need the 'start_station_name' column anymore, you can drop it
# stations.drop('start_station_name', axis=1, inplace=True)

# %%
stations.drop('start_station_name', axis=1, inplace=True)

# %%
display(stations.isna().sum())
# Out:
# station_name        0
# net_total           0
# start_station_id    1
# start_lat           1
# start_lng           1
# dtype: int64

# %%
# Create a DataFrame of unique end stations from 'classic'
unique_end_stations = electric[['end_station_name', 'end_station_id', 'end_lat', 'end_lng']].drop_duplicates('end_station_name')

# Merge with 'stations' DataFrame where the 'start_station_id' is NaN
nan_stations = stations[stations['start_station_id'].isna()]
updated_nan_stations = nan_stations.merge(unique_end_stations, left_on='station_name', right_on='end_station_name', how='left')

# Now, updated_nan_stations contains the rows with NaN filled in from the 'end' columns where possible
# Rename the columns to match the 'stations' DataFrame
updated_nan_stations.drop(['start_station_id','start_lat','start_lng'], axis=1, inplace=True)
updated_nan_stations.rename(columns={
    'end_station_id': 'start_station_id',
    'end_lat': 'start_lat',
    'end_lng': 'start_lng'
}, inplace=True)

# Drop the unwanted 'end_station_name' column
updated_nan_stations.drop('end_station_name', axis=1, inplace=True)

# %%
# Now, let's update the stations DataFrame
nan_mask = stations['start_station_id'].isna()
for column in ['start_station_id', 'start_lat', 'start_lng']:
    # Use 'station_name' to align the updated data correctly
    stations.loc[nan_mask, column] = stations.loc[nan_mask, 'station_name'].map(updated_nan_stations.set_index('station_name')[column])

# %%
display(endstation_value_counts.head())
# Out:
# end_station_name
# 14th & Irving St NW            10629
# Adams Mill & Columbia Rd NW     9776
# Lamont & Mt Pleasant NW         9529
# 1st & M St NE                   9436
# 15th & P St NW                  8568
# Name: count, dtype: int64

# %%
# Ensure the index of the Series is named 'station_name'
startstation_value_counts.index.name = 'station_name'
endstation_value_counts.index.name = 'station_name'

# Convert the Series to a DataFrame
start_counts_df = startstation_value_counts.reset_index().rename(columns={startstation_value_counts.name: 'start_count'})
end_counts_df = endstation_value_counts.reset_index().rename(columns={endstation_value_counts.name: 'end_count'})

# Merge with the 'stations' DataFrame on 'station_name'
stations = stations.merge(start_counts_df, on='station_name', how='left')
stations = stations.merge(end_counts_df, on='station_name', how='left')

# %%
display(stations.sample(15))
# Out:
#                                           station_name  net_total  \
# 385                                  Fort Totten Metro      289.0
# 550                          N Pershing Dr & Quebec St        2.0
# 133                                     21st & I St NW       65.0
# 626                               Prince St & Union St       24.0
# 612                                Pimmit Dr & Idyl Ln        4.0
# 148                      25th St & Pennsylvania Ave NW       12.0
# 298                    Columbia Pike & S Courthouse Rd        7.0
# 348                                Eads St & 12th St S       26.0
# 125                1st & Washington Hospital Center NW      328.0
# 410                            Georgia Ave & Spring St        7.0
# 344               Duke St & Strand (Robinson Terminal)        3.0
# 680                         S Wakefield St & 28th Rd S        1.0
# 586  North Shore & Cameron Crescent Dr/Crescent Apa...        1.0
# 246                        Arlington Blvd & Ft Myer Dr        1.0
# 0                                       10th & E St NW        9.0
#
#     start_station_id  start_lat  start_lng  start_count  end_count
# 385          31515.0  38.952369 -77.002635       3559.0     3270.0
# 550          31973.0  38.874273 -77.104823         96.0       94.0
# 133          31205.0  38.900741 -77.046399       3803.0     3738.0
# 626          31041.0  38.803120 -77.040377        948.0      924.0
# 612          32264.0  38.897675 -77.207232         17.0       13.0
# 148          31237.0  38.903826 -77.053415       2565.0     2553.0
# 298          31053.0  38.863955 -77.080328        814.0      807.0
# 348          31071.0  38.862813 -77.054322       1745.0     1719.0
# 125          31507.0  38.928762 -77.012387       2893.0     2565.0
# 410          32035.0  38.999429 -77.031597        268.0      261.0
# 344          31933.0  38.801921 -77.040327        242.0      239.0
# 680          31972.0  38.844021 -77.098063         32.0       31.0
# 586          32209.0  38.970131 -77.338649         76.0       75.0
# 246          31937.0  38.890795 -77.074868        746.0      745.0
# 0            31256.0  38.895979 -77.026017       2580.0     2571.0

# %%
stations['start_count'].fillna(0, inplace=True)
stations['end_count'].fillna(0, inplace=True)

# %%
display(electric.sample(5))
# Out:
#                   ride_id          started_at            ended_at  \
# 453972   F7EE3881EA1277D0 2021-04-15 01:35:18 2021-04-15 01:40:15
# 1112817  9EF014088DD6A94E 2021-07-03 01:49:08 2021-07-03 02:07:27
# 541349   98091D2159C7B4F8 2021-04-27 16:20:47 2021-04-27 16:46:43
# 4478336  056B432A271F22F7 2022-07-14 18:26:20 2022-07-14 18:54:55
# 4397721  BE4AC7E8AD789383 2022-07-08 08:32:07 2022-07-08 08:37:18
#
#                                 start_station_name start_station_id  \
# 453972           Ward Circle / American University          31301.0
# 1112817                                        NaN              NaN
# 541349         Broad Branch Rd & Northampton St NW          31422.0
# 4478336                                        NaN              NaN
# 4397721  Lincoln Park / 13th & East Capitol St NE           31619.0
#
#                                      end_station_name end_station_id  \
# 453972               Wisconsin Ave & Brandywine St NW        31319.0
# 1112817                         Maine Ave & 7th St SW        31609.0
# 541349                               Hardy Rec Center        31326.0
# 4478336                                           NaN            NaN
# 4397721  Eastern Market / 7th & North Carolina Ave SE        31610.0
#
#          start_lat  start_lng    end_lat    end_lng member_casual  weekend  \
# 453972   38.938764 -77.087193  38.949824 -77.080200        casual    False
# 1112817  38.880000 -77.010000  38.878671 -77.023055        casual     True
# 541349   38.965787 -77.068605  38.909656 -77.085596        member    False
# 4478336  38.920000 -77.030000  38.900000 -76.990000        member    False
# 4397721  38.890422 -76.988383  38.886952 -76.996806        member    False
#
#          morning
# 453972      True
# 1112817     True
# 541349     False
# 4478336    False
# 4397721     True

# %%
# Filter for AM: 'weekend' is False and 'morning' is True
am_filter = (electric['weekend'] == False) & (electric['morning'] == True)
# Filter for PM: 'weekend' is False and 'morning' is False
pm_filter = (electric['weekend'] == False) & (electric['morning'] == False)

# Count the start stations for AM and PM
weekday_am_startstation_value_counts = electric.loc[am_filter, 'start_station_name'].value_counts()
weekday_pm_startstation_value_counts = electric.loc[pm_filter, 'start_station_name'].value_counts()

# Count the end stations for AM and PM
weekday_am_endstation_value_counts = electric.loc[am_filter, 'end_station_name'].value_counts()
weekday_pm_endstation_value_counts = electric.loc[pm_filter, 'end_station_name'].value_counts()

# Calculate the net total for each station for AM and PM
weekday_am_net = weekday_am_startstation_value_counts.subtract(weekday_am_endstation_value_counts, fill_value=0)
weekday_pm_net = weekday_pm_startstation_value_counts.subtract(weekday_pm_endstation_value_counts, fill_value=0)

# %%
display(weekday_am_net.head())
# Out:
# 10th & E St NW          -375.0
# 10th & Florida Ave NW    102.0
# 10th & G St NW          -345.0
# 10th & H St NE           122.0
# 10th & K St NW          -210.0
# Name: count, dtype: float64

# %%
# Ensure the index of the Series is named 'station_name'
weekday_am_net.index.name = 'station_name'
weekday_pm_net.index.name = 'station_name'

# Convert the Series to a DataFrame
weekday_am_df = weekday_am_net.reset_index().rename(columns={weekday_am_net.name: 'weekday_am_net'})
weekday_pm_df = weekday_pm_net.reset_index().rename(columns={weekday_pm_net.name: 'weekday_pm_net'})

# Merge with the 'stations' DataFrame on 'station_name'
stations = stations.merge(weekday_am_df, on='station_name', how='left')
stations = stations.merge(weekday_pm_df, on='station_name', how='left')

# %%
display(stations.sample(5))
# Out:
#                 station_name  net_total start_station_id  start_lat  \
# 738             Union Market      -26.0          31517.0  38.907868
# 635  Reston Regional Library        5.0          32211.0  38.962137
# 382    Florida Ave & R St NW       69.0          31503.0  38.912529
# 44            14th & G St NW       15.0          31238.0  38.898302
# 452   Kenmore St & 24th St S       -6.0          31061.0  38.848456
#
#      start_lng  start_count  end_count  weekday_am_net  weekday_pm_net
# 738 -76.997064       3643.0     3669.0          -205.0           196.0
# 635 -77.358788         10.0        5.0             0.0             2.0
# 382 -77.013435       2584.0     2515.0           199.0          -124.0
# 44  -77.031810       2296.0     2281.0          -542.0           540.0
# 452 -77.084921        279.0      285.0            -5.0             4.0

# %%
# Filter for AM: 'weekend' is False and 'morning' is True
fun_am_filter = (electric['weekend'] == True) & (electric['morning'] == True)
# Filter for PM: 'weekend' is False and 'morning' is False
fun_pm_filter = (electric['weekend'] == True) & (electric['morning'] == False)

# Count the start stations for AM and PM
fun_am_startstation_value_counts = electric.loc[fun_am_filter, 'start_station_name'].value_counts()
fun_pm_startstation_value_counts = electric.loc[fun_pm_filter, 'start_station_name'].value_counts()

# Count the end stations for AM and PM
fun_am_endstation_value_counts = electric.loc[fun_am_filter, 'end_station_name'].value_counts()
fun_pm_endstation_value_counts = electric.loc[fun_pm_filter, 'end_station_name'].value_counts()

# Calculate the net total for each station for AM and PM
fun_am_net = fun_am_startstation_value_counts.subtract(fun_am_endstation_value_counts, fill_value=0)
fun_pm_net = fun_pm_startstation_value_counts.subtract(fun_pm_endstation_value_counts, fill_value=0)

# %%
# Ensure the index of the Series is named 'station_name'
fun_am_net.index.name = 'station_name'
fun_pm_net.index.name = 'station_name'

# Convert the Series to a DataFrame
fun_am_df = fun_am_net.reset_index().rename(columns={fun_am_net.name: 'fun_am_net'})
fun_pm_df = fun_pm_net.reset_index().rename(columns={fun_pm_net.name: 'fun_pm_net'})

# Merge with the 'stations' DataFrame on 'station_name'
stations = stations.merge(fun_am_df, on='station_name', how='left')
stations = stations.merge(fun_pm_df, on='station_name', how='left')

# %%
print(stations.columns)
# Out:
# Index(['station_name', 'net_total', 'start_station_id', 'start_lat',
#        'start_lng', 'start_count', 'end_count', 'weekday_am_net',
#        'weekday_pm_net', 'fun_am_net', 'fun_pm_net'],
#       dtype='object')

# %%
stations = stations.reindex(columns=['station_name','start_count', 'end_count', 'net_total', 'weekday_am_net',
       'weekday_pm_net', 'fun_am_net', 'fun_pm_net', 'start_station_id', 'start_lat',
       'start_lng'])
display(stations.sample(5))
# Out:
#                                   station_name  start_count  end_count  \
# 492  Lincoln Park / 13th & East Capitol St NE        3300.0     3200.0
# 289        Chillum Rd & Riggs Rd / Riggs Plaza        771.0      725.0
# 192                           4th St & K St NW       1733.0     1710.0
# 62   14th St Heights / 14th & Crittenden St NW       1242.0     1149.0
# 130              20th & O St NW / Dupont South       4142.0     4095.0
#
#      net_total  weekday_am_net  weekday_pm_net  fun_am_net  fun_pm_net  \
# 492      100.0           501.0          -398.0        75.0       -78.0
# 289       46.0           113.0           -67.0        19.0       -19.0
# 192       23.0             8.0            19.0       -15.0        11.0
# 62        93.0            88.0           -12.0        -5.0        22.0
# 130       47.0          -180.0           208.0       -47.0        66.0
#
#     start_station_id  start_lat  start_lng
# 492          31619.0  38.890447 -76.988364
# 289          32416.0  38.961740 -76.995934
# 192          31642.0  38.902396 -77.015932
# 62           31402.0  38.947698 -77.032890
# 130          31234.0  38.908933 -77.044673

# %%
stations['weekday_am_net'] = stations['weekday_am_net'] * -1
stations['weekday_pm_net'] = stations['weekday_pm_net'] * -1
stations['fun_am_net'] = stations['fun_am_net'] * -1
stations['fun_pm_net'] = stations['fun_pm_net'] * -1

# %%
stations['net_total'] = stations['net_total'] * -1

# %%
stations = stations.fillna(0)

# %%
copy_stations = stations.copy()

# %%
display(stations.sample(10))
# Out:
#                                        station_name  start_count  end_count  \
# 383                    Fort Lincoln Dr & 33rd Pl NE        124.0      121.0
# 1                             10th & Florida Ave NW       3175.0     3105.0
# 693                  South Capitol & Atlantic St SW        267.0      266.0
# 235  Anacostia Ave & Benning Rd NE / River Terrace         498.0      473.0
# 346                  E Fairfax St & S Washington St        103.0       96.0
# 702                         St Asaph & Pendleton St        304.0      293.0
# 427                              Hamlin & 7th St NE       2081.0     1983.0
# 617                   Potomac & Pennsylvania Ave SE       3529.0     3510.0
# 72                                   15th & W St NW       5994.0     5891.0
# 311                        Commerce St & Fayette St        248.0      245.0
#
#      net_total  weekday_am_net  weekday_pm_net  fun_am_net  fun_pm_net  \
# 383       -3.0             5.0            -3.0         9.0       -14.0
# 1        -70.0          -102.0            61.0       -21.0        -8.0
# 693       -1.0            29.0           -34.0         7.0        -3.0
# 235      -25.0            19.0           -29.0       -27.0        12.0
# 346       -7.0           -22.0            14.0         2.0        -1.0
# 702      -11.0            24.0           -22.0        -5.0        -8.0
# 427      -98.0          -374.0           313.0       -63.0        26.0
# 617      -19.0          -293.0           314.0       -75.0        35.0
# 72      -103.0          -186.0           117.0       -36.0         2.0
# 311       -3.0            -2.0            -4.0         8.0        -5.0
#
#     start_station_id  start_lat  start_lng
# 383          31537.0  38.921660 -76.955692
# 1            31120.0  38.920315 -77.025616
# 693          31811.0  38.831538 -77.008095
# 235          31708.0  38.896526 -76.960092
# 346          32604.0  38.880585 -77.171942
# 702          31043.0  38.810829 -77.044555
# 427          31514.0  38.927521 -76.997145
# 617          31606.0  38.880312 -76.986253
# 72           31125.0  38.919041 -77.034447
# 311          31045.0  38.805637 -77.052924

# %%
display(stations.describe())
# Out:
#         start_count     end_count    net_total  weekday_am_net  \
# count    812.000000    812.000000   812.000000      812.000000
# mean    1295.992611   1258.131773   -37.860837       -3.461823
# std     1767.377652   1708.344212   108.757047      203.405288
# min        0.000000      0.000000 -1381.000000    -1231.000000
# 25%      135.750000    136.000000   -36.000000      -52.250000
# 50%      511.000000    502.500000   -10.000000       -2.000000
# 75%     1838.500000   1775.500000    -2.000000       34.250000
# max    11680.000000  10629.000000    59.000000     1136.000000
#
#        weekday_pm_net  fun_am_net  fun_pm_net   start_lat   start_lng
# count      812.000000  812.000000  812.000000  812.000000  812.000000
# mean       -23.258621   -2.684729   -8.455665   38.910184  -77.066957
# std        178.830554   49.949584   45.940311    0.061679    0.091875
# min      -1242.000000 -296.000000 -228.000000   38.782641  -77.368379
# 25%        -49.000000  -12.000000  -17.000000   38.877952  -77.095194
# 50%         -1.000000   -0.000000   -1.000000   38.899990  -77.045297
# 75%         35.000000    9.000000    6.000000   38.932720  -77.012206
# max        745.000000  225.000000  277.000000   39.125780  -76.825590

# %%
display(stations.sort_values('net_total').head(20))
# Out:
#                                           station_name  start_count  \
# 600                            Park Rd & Holmead Pl NW       7382.0
# 19                                 11th & Kenyon St NW       7112.0
# 47                                 14th & Irving St NW      11680.0
# 50                                 14th & Newton St NW       6246.0
# 51                                   14th & Otis Pl NW       6067.0
# 307                       Columbia Rd & Georgia Ave NW       5731.0
# 22                                   11th & Park Rd NW       6549.0
# 403                     Georgia & New Hampshire Ave NW       6180.0
# 473                            Lamont & Mt Pleasant NW      10077.0
# 418                                       Grant Circle       3275.0
# 46                                14th & Harvard St NW       3043.0
# 17                                 11th & Girard St NW       6539.0
# 448                         Kansas Ave & Sherman Cr NW       4249.0
# 295                           Columbia & Ontario Rd NW       8763.0
# 61                              14th St & Spring Rd NW       7564.0
# 125                1st & Washington Hospital Center NW       2893.0
# 385                                  Fort Totten Metro       3559.0
# 45                                 14th & Girard St NW       4037.0
# 78                                16th & Harvard St NW       3575.0
# 808  Woodley Park Metro / Calvert St & Connecticut ...       3590.0
#
#      end_count  net_total  weekday_am_net  weekday_pm_net  fun_am_net  \
# 600     6001.0    -1381.0          -803.0          -279.0      -193.0
# 19      6053.0    -1059.0          -876.0            44.0      -237.0
# 47     10629.0    -1051.0          -520.0          -295.0      -153.0
# 50      5261.0     -985.0          -766.0           -48.0      -179.0
# 51      5146.0     -921.0          -826.0           125.0      -232.0
# 307     4917.0     -814.0         -1129.0           482.0      -248.0
# 22      5813.0     -736.0          -670.0            53.0      -160.0
# 403     5630.0     -550.0          -485.0            30.0      -120.0
# 473     9529.0     -548.0         -1231.0           737.0      -278.0
# 418     2755.0     -520.0          -800.0           393.0      -182.0
# 46      2637.0     -406.0          -486.0           136.0      -101.0
# 17      6142.0     -397.0          -893.0           575.0      -230.0
# 448     3854.0     -395.0          -934.0           673.0      -289.0
# 295     8394.0     -369.0          -364.0            82.0       -76.0
# 61      7219.0     -345.0          -878.0           632.0      -236.0
# 125     2565.0     -328.0           500.0          -801.0        51.0
# 385     3270.0     -289.0           435.0          -656.0       130.0
# 45      3769.0     -268.0          -581.0           418.0      -155.0
# 78      3312.0     -263.0          -253.0            44.0      -102.0
# 808     3342.0     -248.0          -117.0           -53.0       -23.0
#
#      fun_pm_net start_station_id  start_lat  start_lng
# 600      -106.0          31602.0  38.930813 -77.031458
# 19         10.0          31102.0  38.929552 -77.027809
# 47        -83.0          31124.0  38.928605 -77.032294
# 50          8.0          31649.0  38.932016 -77.032967
# 51         12.0          31131.0  38.934263 -77.032643
# 307        81.0          31115.0  38.928081 -77.023768
# 22         41.0          31651.0  38.931411 -77.028215
# 403        25.0          31400.0  38.936821 -77.024116
# 473       224.0          31107.0  38.932019 -77.038753
# 418        69.0          31421.0  38.942051 -77.018208
# 46         45.0          31105.0  38.926715 -77.032145
# 17        151.0          31126.0  38.925652 -77.027132
# 448       155.0          31417.0  38.948259 -77.021975
# 295       -11.0          31296.0  38.924157 -77.040765
# 61        137.0          31401.0  38.937482 -77.032902
# 125       -78.0          31507.0  38.928762 -77.012387
# 385      -198.0          31515.0  38.952369 -77.002635
# 45         50.0          31123.0  38.925368 -77.032410
# 78         48.0          31103.0  38.926105 -77.036640
# 808       -55.0          31323.0  38.923440 -77.051902

# %%
# Calculate the 'bike add ratio' column as described
stations['bike_add_ratio'] = np.where(
    (stations['start_count'] + stations['end_count']) != 0,  # avoid division by zero
    stations['end_count'] / (stations['start_count'] + stations['end_count']),
    0  # set unbalanced to 0 if there's no start or end count
)

# %%
stations['bike_add_ratio'] = (stations['bike_add_ratio'] * 100).round(1)

# %%
stations['daily_usage'] = ((stations['start_count'] + stations['end_count']) / 911).round(2)

# %%
display(stations.sort_values('start_count').tail(5))
# Out:
#                     station_name  start_count  end_count  net_total  \
# 295     Columbia & Ontario Rd NW       8763.0     8394.0     -369.0
# 117                1st & M St NE       9497.0     9436.0      -61.0
# 229  Adams Mill & Columbia Rd NW       9980.0     9776.0     -204.0
# 473      Lamont & Mt Pleasant NW      10077.0     9529.0     -548.0
# 47           14th & Irving St NW      11680.0    10629.0    -1051.0
#
#      weekday_am_net  weekday_pm_net  fun_am_net  fun_pm_net start_station_id  \
# 295          -364.0            82.0       -76.0       -11.0          31296.0
# 117            28.0           -32.0       -15.0       -42.0          31603.0
# 229          -110.0            16.0       -11.0       -99.0          31104.0
# 473         -1231.0           737.0      -278.0       224.0          31107.0
# 47           -520.0          -295.0      -153.0       -83.0          31124.0
#
#      start_lat  start_lng  bike_add_ratio  daily_usage
# 295  38.924157 -77.040765            48.9        18.83
# 117  38.905648 -77.005584            49.8        20.78
# 229  38.923081 -77.042569            49.5        21.69
# 473  38.932019 -77.038753            48.6        21.52
# 47   38.928605 -77.032294            47.6        24.49

# %%
display(stations.sort_values('end_count').tail(5))
# Out:
#                     station_name  start_count  end_count  net_total  \
# 71                15th & P St NW       8636.0     8568.0      -68.0
# 117                1st & M St NE       9497.0     9436.0      -61.0
# 473      Lamont & Mt Pleasant NW      10077.0     9529.0     -548.0
# 229  Adams Mill & Columbia Rd NW       9980.0     9776.0     -204.0
# 47           14th & Irving St NW      11680.0    10629.0    -1051.0
#
#      weekday_am_net  weekday_pm_net  fun_am_net  fun_pm_net start_station_id  \
# 71            160.0          -202.0        26.0       -52.0          31201.0
# 117            28.0           -32.0       -15.0       -42.0          31603.0
# 473         -1231.0           737.0      -278.0       224.0          31107.0
# 229          -110.0            16.0       -11.0       -99.0          31104.0
# 47           -520.0          -295.0      -153.0       -83.0          31124.0
#
#      start_lat  start_lng  bike_add_ratio  daily_usage
# 71   38.909892 -77.034337            49.8        18.88
# 117  38.905648 -77.005584            49.8        20.78
# 473  38.932019 -77.038753            48.6        21.52
# 229  38.923081 -77.042569            49.5        21.69
# 47   38.928605 -77.032294            47.6        24.49

# %%
display(stations.describe())
# Out:
#         start_count     end_count    net_total  weekday_am_net  \
# count    812.000000    812.000000   812.000000      812.000000
# mean    1295.992611   1258.131773   -37.860837       -3.461823
# std     1767.377652   1708.344212   108.757047      203.405288
# min        0.000000      0.000000 -1381.000000    -1231.000000
# 25%      135.750000    136.000000   -36.000000      -52.250000
# 50%      511.000000    502.500000   -10.000000       -2.000000
# 75%     1838.500000   1775.500000    -2.000000       34.250000
# max    11680.000000  10629.000000    59.000000     1136.000000
#
#        weekday_pm_net  fun_am_net  fun_pm_net   start_lat   start_lng  \
# count      812.000000  812.000000  812.000000  812.000000  812.000000
# mean       -23.258621   -2.684729   -8.455665   38.910184  -77.066957
# std        178.830554   49.949584   45.940311    0.061679    0.091875
# min      -1242.000000 -296.000000 -228.000000   38.782641  -77.368379
# 25%        -49.000000  -12.000000  -17.000000   38.877952  -77.095194
# 50%         -1.000000   -0.000000   -1.000000   38.899990  -77.045297
# 75%         35.000000    9.000000    6.000000   38.932720  -77.012206
# max        745.000000  225.000000  277.000000   39.125780  -76.825590
#
#        bike_add_ratio  daily_usage
# count      812.000000   812.000000
# mean        49.272414     2.803707
# std          3.423568     3.813848
# min          0.000000     0.000000
# 25%         48.900000     0.300000
# 50%         49.600000     1.105000
# 75%         49.900000     3.960000
# max        100.000000    24.490000

# %%
display(stations.sort_values('net_total').head(20))
display(stations.sort_values('net_total').tail(20))
# Out:
#                                           station_name  start_count  \
# 600                            Park Rd & Holmead Pl NW       7382.0
# 19                                 11th & Kenyon St NW       7112.0
# 47                                 14th & Irving St NW      11680.0
# 50                                 14th & Newton St NW       6246.0
# 51                                   14th & Otis Pl NW       6067.0
# 307                       Columbia Rd & Georgia Ave NW       5731.0
# 22                                   11th & Park Rd NW       6549.0
# 403                     Georgia & New Hampshire Ave NW       6180.0
# 473                            Lamont & Mt Pleasant NW      10077.0
# 418                                       Grant Circle       3275.0
# 46                                14th & Harvard St NW       3043.0
# 17                                 11th & Girard St NW       6539.0
# 448                         Kansas Ave & Sherman Cr NW       4249.0
# 295                           Columbia & Ontario Rd NW       8763.0
# 61                              14th St & Spring Rd NW       7564.0
# 125                1st & Washington Hospital Center NW       2893.0
# 385                                  Fort Totten Metro       3559.0
# 45                                 14th & Girard St NW       4037.0
# 78                                16th & Harvard St NW       3575.0
# 808  Woodley Park Metro / Calvert St & Connecticut ...       3590.0
#
#      end_count  net_total  weekday_am_net  weekday_pm_net  fun_am_net  \
# 600     6001.0    -1381.0          -803.0          -279.0      -193.0
# 19      6053.0    -1059.0          -876.0            44.0      -237.0
# 47     10629.0    -1051.0          -520.0          -295.0      -153.0
# 50      5261.0     -985.0          -766.0           -48.0      -179.0
# 51      5146.0     -921.0          -826.0           125.0      -232.0
# 307     4917.0     -814.0         -1129.0           482.0      -248.0
# 22      5813.0     -736.0          -670.0            53.0      -160.0
# 403     5630.0     -550.0          -485.0            30.0      -120.0
# 473     9529.0     -548.0         -1231.0           737.0      -278.0
# 418     2755.0     -520.0          -800.0           393.0      -182.0
# 46      2637.0     -406.0          -486.0           136.0      -101.0
# 17      6142.0     -397.0          -893.0           575.0      -230.0
# 448     3854.0     -395.0          -934.0           673.0      -289.0
# 295     8394.0     -369.0          -364.0            82.0       -76.0
# 61      7219.0     -345.0          -878.0           632.0      -236.0
# 125     2565.0     -328.0           500.0          -801.0        51.0
# 385     3270.0     -289.0           435.0          -656.0       130.0
# 45      3769.0     -268.0          -581.0           418.0      -155.0
# 78      3312.0     -263.0          -253.0            44.0      -102.0
# 808     3342.0     -248.0          -117.0           -53.0       -23.0
#
#      fun_pm_net start_station_id  start_lat  start_lng  bike_add_ratio  \
# 600      -106.0          31602.0  38.930813 -77.031458            44.8
# 19         10.0          31102.0  38.929552 -77.027809            46.0
# 47        -83.0          31124.0  38.928605 -77.032294            47.6
# 50          8.0          31649.0  38.932016 -77.032967            45.7
# 51         12.0          31131.0  38.934263 -77.032643            45.9
# 307        81.0          31115.0  38.928081 -77.023768            46.2
# 22         41.0          31651.0  38.931411 -77.028215            47.0
# 403        25.0          31400.0  38.936821 -77.024116            47.7
# 473       224.0          31107.0  38.932019 -77.038753            48.6
# 418        69.0          31421.0  38.942051 -77.018208            45.7
# 46         45.0          31105.0  38.926715 -77.032145            46.4
# 17        151.0          31126.0  38.925652 -77.027132            48.4
# 448       155.0          31417.0  38.948259 -77.021975            47.6
# 295       -11.0          31296.0  38.924157 -77.040765            48.9
# 61        137.0          31401.0  38.937482 -77.032902            48.8
# 125       -78.0          31507.0  38.928762 -77.012387            47.0
# 385      -198.0          31515.0  38.952369 -77.002635            47.9
# 45         50.0          31123.0  38.925368 -77.032410            48.3
# 78         48.0          31103.0  38.926105 -77.036640            48.1
# 808       -55.0          31323.0  38.923440 -77.051902            48.2
#
#      daily_usage
# 600        14.69
# 19         14.45
# 47         24.49
# 50         12.63
# 51         12.31
# 307        11.69
# 22         13.57
# 403        12.96
# 473        21.52
# 418         6.62
# 46          6.23
# 17         13.92
# 448         8.89
# 295        18.83
# 61         16.23
# 125         5.99
# 385         7.50
# 45          8.57
# 78          7.56
# 808         7.61
#                      station_name  start_count  end_count  net_total  \
# 544       N Howard St & Taney Ave        188.0      195.0        7.0
# 116                 1st & L St NW        317.0      326.0        9.0
# 102            19th & E Street NW        493.0      502.0        9.0
# 292    Clarendon Blvd & Pierce St       1539.0     1549.0       10.0
# 171                 3rd & M st SE        761.0      771.0       10.0
# 228  9th St & Pennsylvania Ave NW        750.0      761.0       11.0
# 115                 1st & K St SE       3302.0     3313.0       11.0
# 560              National Airport       1112.0     1125.0       13.0
# 783                   White House        168.0      181.0       13.0
# 787             Whiting & Lane Dr        116.0      129.0       13.0
# 203                 6th & H St NE       6071.0     6091.0       20.0
# 251        Army Navy Dr & Fern St         99.0      120.0       21.0
# 502        M St & Delaware Ave NE        842.0      863.0       21.0
# 738                  Union Market       3643.0     3669.0       26.0
# 374        Fern St & Army Navy Dr        201.0      231.0       30.0
# 118                 1st & M St SE       3416.0     3451.0       35.0
# 129                20th & L St NW       2540.0     2576.0       36.0
# 170                 3rd & M St SE        812.0      859.0       47.0
# 113                 1st & I St SE       3118.0     3170.0       52.0
# 199             5th & Morse St NE       1247.0     1306.0       59.0
#
#      weekday_am_net  weekday_pm_net  fun_am_net  fun_pm_net start_station_id  \
# 544           -80.0            80.0        -2.0         9.0          31943.0
# 116            -6.0             9.0        -1.0         7.0          31677.0
# 102           219.0          -211.0        11.0       -10.0          31206.0
# 292           -11.0            29.0       -36.0        28.0          31016.0
# 171            33.0           -15.0        -4.0        -4.0          31669.0
# 228           179.0          -172.0        33.0       -29.0          30200.0
# 115           -42.0            43.0         5.0         5.0          31628.0
# 560           226.0          -140.0        67.0      -140.0          31935.0
# 783           150.0          -138.0         9.0        -8.0          31329.0
# 787             4.0            11.0        -4.0         2.0          31942.0
# 203           -75.0           119.0       -15.0        -9.0          31615.0
# 251             8.0            12.0        -1.0         2.0          31936.0
# 502            -3.0            21.0         5.0        -2.0          31627.0
# 738           205.0          -196.0       120.0      -103.0          31517.0
# 374            62.0           -22.0       -15.0         5.0            31936
# 118            37.0             6.0        13.0       -21.0          31650.0
# 129           435.0          -390.0        27.0       -36.0          31250.0
# 170           112.0           -69.0         1.0         3.0          31669.0
# 113            58.0            -4.0        30.0       -32.0          31628.0
# 199            -2.0            35.0        -0.0        26.0          31536.0
#
#      start_lat  start_lng  bike_add_ratio  daily_usage
# 544  38.815788 -77.110108            50.9         0.42
# 116  38.903810 -77.011835            50.7         0.71
# 102  38.895264 -77.043807            50.5         1.09
# 292  38.893496 -77.076421            50.2         3.39
# 171  38.876950 -77.001968            50.3         1.68
# 228  38.894100 -77.024289            50.4         1.66
# 115  38.878863 -77.006049            50.1         7.26
# 560  38.853041 -77.046009            50.3         2.46
# 783  38.895705 -77.037878            51.9         0.38
# 787  38.809876 -77.135887            52.7         0.27
# 203  38.900043 -76.998371            50.1        13.35
# 251  38.864880 -77.056896            54.8         0.24
# 502  38.905427 -77.002901            50.6         1.87
# 738  38.907868 -76.997064            50.2         8.03
# 374  38.864783 -77.056917            53.5         0.47
# 118  38.876805 -77.005706            50.3         7.54
# 129  38.903364 -77.044903            50.4         5.62
# 170  38.876945 -77.002027            51.4         1.83
# 113  38.878891 -77.005982            50.4         6.90
# 199  38.907298 -76.999101            51.2         2.80

# %%
display(stations.describe())
# Out:
#         start_count     end_count    net_total  weekday_am_net  \
# count    812.000000    812.000000   812.000000      812.000000
# mean    1295.992611   1258.131773   -37.860837       -3.461823
# std     1767.377652   1708.344212   108.757047      203.405288
# min        0.000000      0.000000 -1381.000000    -1231.000000
# 25%      135.750000    136.000000   -36.000000      -52.250000
# 50%      511.000000    502.500000   -10.000000       -2.000000
# 75%     1838.500000   1775.500000    -2.000000       34.250000
# max    11680.000000  10629.000000    59.000000     1136.000000
#
#        weekday_pm_net  fun_am_net  fun_pm_net   start_lat   start_lng  \
# count      812.000000  812.000000  812.000000  812.000000  812.000000
# mean       -23.258621   -2.684729   -8.455665   38.910184  -77.066957
# std        178.830554   49.949584   45.940311    0.061679    0.091875
# min      -1242.000000 -296.000000 -228.000000   38.782641  -77.368379
# 25%        -49.000000  -12.000000  -17.000000   38.877952  -77.095194
# 50%         -1.000000   -0.000000   -1.000000   38.899990  -77.045297
# 75%         35.000000    9.000000    6.000000   38.932720  -77.012206
# max        745.000000  225.000000  277.000000   39.125780  -76.825590
#
#        bike_add_ratio  daily_usage
# count      812.000000   812.000000
# mean        49.272414     2.803707
# std          3.423568     3.813848
# min          0.000000     0.000000
# 25%         48.900000     0.300000
# 50%         49.600000     1.105000
# 75%         49.900000     3.960000
# max        100.000000    24.490000

# %%
no_end_station = electric[electric['end_station_name'].isnull()]

# %% [markdown]
# Changing net counts to per-day values

# %%
# Define the date range
start_date = pd.to_datetime('2021-01-01')
end_date = pd.to_datetime('2023-06-30')

# Generate a range of dates
daterange = pd.date_range(start_date, end_date)

# Count weekdays and weekend days
weekdays = ((daterange.dayofweek >= 0) & (daterange.dayofweek <= 4)).sum()
weekends = ((daterange.dayofweek == 5) | (daterange.dayofweek == 6)).sum()

# %%
# Overwrite the 'net' columns with per-day values, rounded to 2 decimal places
stations['weekday_am_net'] = (stations['weekday_am_net'] / weekdays).round(2)
stations['weekday_pm_net'] = (stations['weekday_pm_net'] / weekdays).round(2)
stations['fun_am_net'] = (stations['fun_am_net'] / weekends).round(2)
stations['fun_pm_net'] = (stations['fun_pm_net'] / weekends).round(2)

# %%
stations.rename({'bike_add_ratio': '%_bikes_added'}, axis='columns', inplace=True)

# %%
display(stations.columns)
# Out:
# Index(['station_name', 'start_count', 'end_count', 'net_total',
#        'weekday_am_net', 'weekday_pm_net', 'fun_am_net', 'fun_pm_net',
#        'start_station_id', 'start_lat', 'start_lng', '%_bikes_added',
#        'daily_usage'],
#       dtype='object')

# %%
stations = stations.reindex(columns=['station_name', 'start_count', 'end_count', 'net_total',
       'daily_usage', '%_bikes_added', 'weekday_am_net', 'weekday_pm_net', 'fun_am_net', 'fun_pm_net',
       'start_station_id', 'start_lat', 'start_lng'])

# %%
display(stations.sort_values('net_total').tail(1))
# Out:
#           station_name  start_count  end_count  net_total  daily_usage  \
# 199  5th & Morse St NE       1247.0     1306.0       59.0          2.8
#
#      %_bikes_added  weekday_am_net  weekday_pm_net  fun_am_net  fun_pm_net  \
# 199           51.2            -0.0            0.05        -0.0         0.1
#
#     start_station_id  start_lat  start_lng
# 199          31536.0  38.907298 -76.999101

# %%
import folium

# %%
# Create the base map
m = folium.Map(location=[38.888255,	-77.049436], zoom_start=13)

# Function to create popup text
def create_popup(row):
    return (f"{row['station_name']}<br>"
            f"Daily usage: {row['daily_usage']:.2f}<br>"
            f"% bikes added: {row['%_bikes_added']:.2f}<br>"
            f"Work am: {row['weekday_am_net']}<br>"
            f"Work pm: {row['weekday_pm_net']}<br>"
            f"Fun am: {row['fun_am_net']}<br>"
            f"Fun pm: {row['fun_pm_net']}")

# Stations with the lowest net totals - blue markers
for idx, row in stations.sort_values('net_total').head(25).iterrows():
    folium.Marker(
        location=[row['start_lat'], row['start_lng']],
        popup=folium.Popup(create_popup(row), max_width=300),
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Stations with the highest net totals - orange markers
for idx, row in stations.sort_values('net_total').tail(25).iterrows():
    folium.Marker(
        location=[row['start_lat'], row['start_lng']],
        popup=folium.Popup(create_popup(row), max_width=300),
        icon=folium.Icon(color='orange')
    ).add_to(m)

# %% [markdown]
# Add top 4 stations for daily usage to map

# %%
# Function to create popup text
def create_popup(row):
    return (f"{row['station_name']}<br>"
            f"Daily usage: {row['daily_usage']:.2f}<br>"
            f"% bikes added: {row['%_bikes_added']:.2f}<br>"
            f"Work am: {row['weekday_am_net']}<br>"
            f"Work pm: {row['weekday_pm_net']}<br>"
            f"Fun am: {row['fun_am_net']}<br>"
            f"Fun pm: {row['fun_pm_net']}")

# Stations with the highest daily usage - green markers
for idx, row in stations.sort_values('start_count').tail(4).iterrows():
    folium.Marker(
        location=[row['start_lat'], row['start_lng']],
        popup=folium.Popup(create_popup(row), max_width=300),
        icon=folium.Icon(color='green')
    ).add_to(m)

# %%
# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90432ade6bb3f498c9042ccbefd7f161 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90432ade6bb3f498c9042ccbefd7f161&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90432ade6bb3f498c9042ccbefd7f161 = L.map(
#                 &quot;map_90432ade6bb3f498c9042ccbefd7f161&quot;,
#                 {
#                     center: [38.888255, -77.049436],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa0e270473c6109c205c0a57713ac806 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_90432ade6bb3f498c9042ccbefd7f161);
#
#
#             var marker_6b652a94e71bbaad8803cf18a3ff3c1a = L.marker(
#                 [38.93081266666667, -77.031458],
#                 {}
#             ).addTo(map_90432ade6bb3f498c9042ccbefd7f161);
#
#
#             var icon_b69314f2ef629460e99143111f144fb2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6b652a94e71bbaad8803cf18a3ff3c1a.setIcon(icon_b69314f2ef629460e99143111f144fb2);
#
#
#         var popup_38660efd7a672bb881af6d5315ce6a0d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_c6b0020c0a9084daccafb19b7aa0c2d0 = $(`&lt;div id=&quot;html_c6b0020c0a9084daccafb19b7aa0c2d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Park Rd &amp; Holmead Pl NW&lt;br&gt;Daily usage: 14.69&lt;br&gt;% bikes added: 44.80&lt;br&gt;Work am: -1.23&lt;br&gt;Work pm: -0.43&lt;br&gt;Fun am: -0.74&lt;br&gt;Fun pm: -0.41&lt;/div&gt;`)[0];
#                 popup_38660efd7a672bb881af6d5315ce6a0d.setContent(html_c6b0020c0a9084daccafb19b7aa0c2d0);
#
#
#
#         marker_6b652a94e71bbaad8803cf18a3ff3c1a.bindPopup(popup_38660efd7a672bb881af6d5315ce6a0d)
#         ;
#
#
#
#
#             var marker_d594b286d5a4003e3d81be4e104bfbde = L.marker(
#                 [38.929552, -77.02780883333334],
#                 {}
#             ).addTo(map_90432ade6bb3f498c9042ccbefd7f161);
#
#
#             var icon_75420df95e86b9000e8aa8a38b4f8a9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d594b286d5a4003e3d81be4e104bfbde.setIcon(icon_75420df95e86b9000e8aa8a38b4f8a9a);
#
#
#         var popup_ee2271b1ec66eaba7bd238354fcf18c0 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_b2041d2923d7e508e4e1060dee3ce8ce = $(`&lt;div id=&quot;html_b2041d2923d7e508e4e1060dee3ce8ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11th &amp; Kenyon St NW&lt;br&gt;Daily usage: 14.45&lt;br&gt;% bikes added: 46.00&lt;br&gt;Work am: -1.35&lt;br&gt;Work pm: 0.07&lt;br&gt;Fun am: -0.91&lt;br&gt;Fun pm: 0.04&lt;/div&gt;`)[0];
#                 popup_ee2271b1ec66eaba7bd238354fcf18c0.setContent(html_b2041d2923d7e508e4e1060dee3ce8ce);
#
#
#
#         marker_d594b286d5a4003e3d81be4e104bfbde.bindPopup(popup_ee2271b1ec66eaba7bd238354fcf18c0)
#         ;
#
#
#
#
#             var marker_b7d52f7bb3b405cf6f45605317b8d73f = L.marker(
#                 [38.92860533333333, -77.03229366666666],
#                 {}
#             ).addTo(map_90432ade6bb3f498c9042ccbefd7f161);
#
#
#             var icon_5f3a97b5b3232983f39e8b3f63c2187c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b7d52f7bb3b405cf6f45605317b8d73f.setIcon(icon_5f3a97b5b3232983f39e8b3f63c2187c);
#
#
#         var popup_37f4a04db186694e277cb911ba24ecc1 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_2ac1576008f92ff235a91f580b7b6daf = $(`&lt;div id=&quot;html_2ac1576008f92ff235a91f580b7b6daf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;14th &amp; Irving St NW&lt;br&gt;Daily usage: 24.49&lt;br&gt;% bikes added: 47.60&lt;br&gt;Work am: -0.8&lt;br&gt;Work pm: -0.45&lt;br&gt;Fun am: -0.59&lt;br&gt;Fun pm: -0.32&lt;/div&gt;`)[0];
#                 popup_37f4a04db186694e277cb911ba24ecc1.setContent(html_2ac1576008f92ff235a91f580b7b6daf);
#
#
#
#         marker_b7

# %%
m.save('map.html')
