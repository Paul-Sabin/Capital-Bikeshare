# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import folium

sns.set_theme()

# %%
df = pd.read_csv('C:\\Asus WebStorage\\psabin@gmail.com\\MySyncFolder\\Data Science Course\\Used CSVs\\CSB_2021-2023_All.csv')
display(df.head())
# Out:
# C:\Users\psabi\AppData\Local\Temp\ipykernel_5180\999932228.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Asus WebStorage\\psabin@gmail.com\\MySyncFolder\\Data Science Course\\Used CSVs\\CSB_2021-2023_All.csv')
#             ride_id  rideable_type           started_at             ended_at  \
# 0  5CB9DFCECF79AF84   classic_bike  2021-01-01 00:08:33  2021-01-01 00:33:53
# 1  629E059504606547  electric_bike  2021-01-01 00:13:43  2021-01-01 00:29:34
# 2  E74069873161EE33  electric_bike  2021-01-01 00:14:32  2021-01-01 00:28:45
# 3  91F95E512CABC46A   classic_bike  2021-01-01 00:15:45  2021-01-01 00:21:20
# 4  DA46A05139C0EA2F   classic_bike  2021-01-01 00:17:46  2021-01-01 00:21:00
#
#               start_station_name start_station_id  \
# 0          Maine Ave & 9th St SW          31646.0
# 1                 10th & U St NW          31111.0
# 2          17th & Corcoran St NW          31214.0
# 3  Wilson Blvd. & N. Vermont St.          31926.0
# 4              11th & Park Rd NW          31651.0
#
#                            end_station_name end_station_id  start_lat  \
# 0  Rosslyn Metro / Wilson Blvd & Ft Myer Dr        31015.0  38.880440
# 1                                       NaN            NaN  38.917193
# 2                      14th & Belmont St NW        31119.0  38.912138
# 3             Wilson Blvd. & N. Vermont St.        31926.0  38.879477
# 4                       14th & Newton St NW        31649.0  38.931322
#
#    start_lng    end_lat    end_lng member_casual
# 0 -77.025236  38.894600 -77.072305        member
# 1 -77.025894  38.960000 -77.020000        casual
# 2 -77.038568  38.920870 -77.031691        member
# 3 -77.114563  38.879477 -77.114563        member
# 4 -77.028247  38.931991 -77.032956        member

# %%
df['started_at'] = pd.to_datetime(df['started_at'])
df['ended_at'] = pd.to_datetime(df['ended_at'])
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8180626 entries, 0 to 8180625
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 811.4+ MB
# None

# %%
display(df['rideable_type'].value_counts())
# Out:
# rideable_type
# classic_bike     6157609
# electric_bike    1521056
# docked_bike       501961
# Name: count, dtype: int64

# %%
docked_bike_mask = df['rideable_type'] == 'docked_bike'

# %%
display(df.sample(5))
# Out:
#                   ride_id  rideable_type          started_at  \
# 6008716  D9F30D285B660D83  electric_bike 2022-11-24 01:14:18
# 151366   D820308280762E7C   classic_bike 2021-02-21 13:08:27
# 6971213  326AAF0FFCD3B759    docked_bike 2023-04-04 13:54:51
# 318342   625CFA44173DB7DA    docked_bike 2021-03-27 14:36:42
# 5465837  9ECC7A88B423A405   classic_bike 2022-10-02 09:18:04
#
#                    ended_at  \
# 6008716 2022-11-24 01:22:16
# 151366  2021-02-21 14:35:44
# 6971213 2023-04-04 15:22:34
# 318342  2021-03-27 15:03:06
# 5465837 2022-10-02 09:19:05
#
#                                         start_station_name start_station_id  \
# 6008716                                                NaN              NaN
# 151366                         New Hampshire Ave & T St NW            31229
# 6971213                          Jefferson Dr & 14th St SW          31247.0
# 318342   Smithsonian-National Mall / Jefferson Dr & 12t...          31248.0
# 5465837                                     21st & I St NW          31205.0
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# 6008716                            NaN            NaN  38.910000 -77.020000
# 151366                             NaN            NaN  38.915544 -77.038252
# 6971213      Jefferson Dr & 14th St SW        31247.0  38.888553 -77.032427
# 318342   17th St & Independence Ave SW        31290.0  38.888774 -77.028694
# 5465837              21st St & G st NW        31328.0  38.900711 -77.046449
#
#            end_lat    end_lng member_casual
# 6008716  38.910000 -77.020000        casual
# 151366   38.910000 -77.040000        member
# 6971213  38.888553 -77.032427        casual
# 318342   38.888097 -77.038325        casual
# 5465837  38.898302 -77.046913        member

# %%
display(df[docked_bike_mask]['member_casual'].value_counts())
# Out:
# member_casual
# casual    501957
# member         4
# Name: count, dtype: int64

# %%
classic_mask = df['rideable_type'] == 'classic_bike'
classic = df[classic_mask].copy()
display(classic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6157609 entries, 0 to 8180625
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 657.7+ MB
# None

# %%
classic.drop(['rideable_type'], axis=1, inplace=True)
display(classic.head())
# Out:
#             ride_id          started_at            ended_at  \
# 0  5CB9DFCECF79AF84 2021-01-01 00:08:33 2021-01-01 00:33:53
# 3  91F95E512CABC46A 2021-01-01 00:15:45 2021-01-01 00:21:20
# 4  DA46A05139C0EA2F 2021-01-01 00:17:46 2021-01-01 00:21:00
# 6  0535306B61EF92F9 2021-01-01 00:19:06 2021-01-01 00:36:28
# 9  874D92427D41BC30 2021-01-01 00:21:39 2021-01-01 00:31:07
#
#                start_station_name start_station_id  \
# 0           Maine Ave & 9th St SW          31646.0
# 3   Wilson Blvd. & N. Vermont St.          31926.0
# 4               11th & Park Rd NW          31651.0
# 6  Bladensburg Rd & Benning Rd NE          31617.0
# 9               14th & Otis Pl NW          31131.0
#
#                            end_station_name end_station_id  start_lat  \
# 0  Rosslyn Metro / Wilson Blvd & Ft Myer Dr        31015.0  38.880440
# 3             Wilson Blvd. & N. Vermont St.        31926.0  38.879477
# 4                       14th & Newton St NW        31649.0  38.931322
# 6                 Good Hope Rd & MLK Ave SE        31802.0  38.900413
# 9                            14th & R St NW        31202.0  38.934405
#
#    start_lng    end_lat    end_lng member_casual
# 0 -77.025236  38.894600 -77.072305        member
# 3 -77.114563  38.879477 -77.114563        member
# 4 -77.028247  38.931991 -77.032956        member
# 6 -76.982872  38.867373 -76.988039        casual
# 9 -77.032687  38.913046 -77.032008        member

# %%
display(classic.tail())
# Out:
#                   ride_id          started_at            ended_at  \
# 8180616  02F192BCA07B45AF 2023-06-30 23:56:15 2023-07-01 00:02:41
# 8180618  A23BD8CBD6322DD3 2023-06-30 23:56:49 2023-07-01 00:43:54
# 8180622  0448FEEB78F2B08D 2023-06-30 23:58:14 2023-07-01 00:24:14
# 8180623  5BE258BC59548BE9 2023-06-30 23:58:26 2023-07-01 00:20:06
# 8180625  31813068FD8A3720 2023-06-30 23:59:35 2023-07-01 00:38:55
#
#                         start_station_name start_station_id  \
# 8180616  Park Pl & Rock Creek Church Rd NW          31137.0
# 8180618      15th St & Constitution Ave NW          31321.0
# 8180622        18th & New Hampshire Ave NW          31324.0
# 8180623        18th & New Hampshire Ave NW          31324.0
# 8180625           National Harbor Carousel          32423.0
#
#                              end_station_name end_station_id  start_lat  \
# 8180616                   11th & Kenyon St NW        31102.0  38.937135
# 8180618         14th St & Rhode Island Ave NW        31203.0  38.892244
# 8180622  Massachusetts Ave & Dupont Circle NW        31200.0  38.911268
# 8180623  Massachusetts Ave & Dupont Circle NW        31200.0  38.911268
# 8180625              National Harbor Carousel        32423.0  38.785900
#
#          start_lng    end_lat    end_lng member_casual
# 8180616 -77.019125  38.929464 -77.027822        member
# 8180618 -77.033234  38.908600 -77.032300        casual
# 8180622 -77.041829  38.910100 -77.044400        casual
# 8180623 -77.041829  38.910100 -77.044400        casual
# 8180625 -77.016700  38.785900 -77.016700        casual

# %%
electric_bike_mask = df['rideable_type'] == 'electric_bike'
station_value_counts_electic = df[electric_bike_mask]['start_station_id'].value_counts()

# %%
endstation_value_counts_electric = df[electric_bike_mask]['end_station_id'].value_counts()

# %%
classic['weekend'] = classic['started_at'].dt.dayofweek >= 5

# %%
# Assuming 'start_time' is your datetime column:
classic['morning'] = classic['started_at'].dt.hour.between(1, 13)

# %%
display(classic.sample(20))
# Out:
#                   ride_id          started_at            ended_at  \
# 5791374  C6D0586CEB817F9A 2022-10-31 21:29:31 2022-10-31 21:32:33
# 634980   D147A3A4CF62213F 2021-05-10 12:40:30 2021-05-10 12:51:57
# 6121013  AB730107007BED7F 2022-12-09 20:58:40 2022-12-09 21:20:18
# 2780242  51AE7701C43FBB2F 2022-01-11 18:05:05 2022-01-11 18:19:03
# 6033253  4AA7EBD69BBD1B8D 2022-11-28 16:19:00 2022-11-28 16:25:14
# 7192742  4B30672DC9E9D2DB 2023-04-20 15:08:16 2023-04-20 15:41:12
# 1025018  A548723796007CBA 2021-06-23 19:21:01 2021-06-23 19:40:09
# 6333239  2C466D04B12F7613 2023-01-16 18:46:40 2023-01-16 19:02:00
# 1186215  9091F6AFE58E87CE 2021-07-09 22:18:46 2021-07-09 22:27:24
# 21979    0B12F7428B6E0711 2021-01-08 13:39:20 2021-01-08 13:48:39
# 6875802  550336B7F2192D54 2023-03-27 17:14:13 2023-03-27 17:25:49
# 6350085  08D508046C37A495 2023-01-19 10:13:19 2023-01-19 10:30:42
# 4691181  050D28EDB4344CB9 2022-07-31 15:02:40 2022-07-31 15:08:25
# 2003438  3CBBB42178A49C45 2021-10-02 11:03:43 2021-10-02 11:26:14
# 5430415  16B7727581433735 2022-09-28 16:56:21 2022-09-28 17:10:55
# 199847   91BF134D6696E198 2021-03-06 17:15:02 2021-03-06 17:32:14
# 4444044  9DABAD4DE82DF9FC 2022-07-11 22:37:10 2022-07-11 22:48:11
# 6350085  38.902932 -76.998405  38.903658 -77.031737        member    False
# 4691181  38.915544 -77.038252  38.909801 -77.034427        casual     True
# 2003438  38.888255 -77.049436  38.879819 -77.037413        casual     True
# 5430415  38.928552 -77.032224  38.900283 -77.029822        casual    False
# 199847   38.875010 -77.002400  38.900412 -77.001949        member     True
# 4444044  38.907316 -77.000698  38.922404 -76.996023        casual    False
# 6715737  38.917761 -77.040620  38.909801 -77.034427        member    False
# 5282394  38.910674 -77.031880  38.898164 -77.031898        casual     True
# 5393249  38.912100 -77.038700  38.893028 -77.026013        member     True
#
#          morning
# 5791374    False
# 634980      True
# 6121013    False
# 2780242    False
# 6033253    False
# 7192742    False
# 1025018    False
# 6333239    False
# 1186215    False
# 21979       True
# 6875802    False
# 6350085     True
# 4691181    False
# 2003438     True
# 5430415    False
# 199847     False
# 4444044    False
# 6715737    False
# 5282394    False
# 5393249    False

# %%
endstation_value_counts = classic['end_station_name'].value_counts()
display(endstation_value_counts.head(50))
# Out:
# end_station_name
# New Hampshire Ave & T St NW                              72098
# 15th & P St NW                                           68783
# Columbus Circle / Union Station                          66962
# 1st & M St NE                                            60135
# Lincoln Memorial                                         53400
# Massachusetts Ave & Dupont Circle NW                     53196
# 5th & K St NW                                            53147
# 14th & V St NW                                           51468
# Jefferson Dr & 14th St SW                                50654
# 4th St & Madison Dr NW                                   50056
# Eastern Market Metro / Pennsylvania Ave & 8th St SE      49880
# 14th & R St NW                                           47207
# 8th & O St NW                                            46682
# 17th & Corcoran St NW                                    45917
# Smithsonian-National Mall / Jefferson Dr & 12th St SW    44749
# 15th & W St NW                                           44600
# 11th & M St NW                                           44596
# Henry Bacon Dr & Lincoln Memorial Circle NW              44070
# 4th & M St SW                                            42859
# 6th & H St NE                                            42710
# 3rd & M St NE                                            41464
# New Hampshire Ave & Ward Pl NW                           41375
# 23rd & M St NW                                           40222
# Thomas Circle                                            39979
# 14th & Rhode Island Ave NW                               39247
# 8th & H St NW                                            37919
# 7th & F St NW / National Portrait Gallery                37715
# M St & Pennsylvania Ave NW                               37419
# 5th St & Massachusetts Ave NW                            35930
# 18th & New Hampshire Ave NW                              35577
# 7th & K St NW                                            35214
# New Jersey Ave & F St NW                                 34701
# California St & Florida Ave NW                           34683
# Maine Ave & 7th St SW                                    33829
# Maine Ave & 9th St SW                                    33400
# Jefferson Memorial                                       32834
# 17th St & Massachusetts Ave NW                           32599
# Metro Center / 12th & G St NW                            32298
# 15th St & Constitution Ave NW                            32243
# 18th St & Wyoming Ave NW                                 31943
# 25th St & Pennsylvania Ave NW                            31922
# 3rd & H St NE                                            31801
# 20th & O St NW / Dupont South                            31790
# 17th & K St NW                                           31521
# 18th & R St NW                                           31231
# 1st & K St NE                                            30822
# New Hampshire Ave & 24th St NW                           30773
# 22nd & I St NW / Foggy Bottom                            30771
# Eckington Pl & Q St NE                                   30666
# 21st & I St NW                                           30567
# Name: count, dtype: int64

# %%
# Count the start stations
startstation_value_counts = classic['start_station_name'].value_counts()

# Count the end stations (already done in your case)
endstation_value_counts = classic['end_station_name'].value_counts()

# Calculate the net total for each station
# Subtracting the Series will align on the index automatically
net_total = startstation_value_counts.subtract(endstation_value_counts, fill_value=0)

# net_total now contains the net total for each station.
# If a station name doesn't exist in one of the Series, it assumes a count of 0 for subtraction
display(net_total.head(20))
# Out:
# 10th & E St NW                             -3336.0
# 10th & Florida Ave NW                        221.0
# 10th & G St NW                             -5159.0
# 10th & H St NE                              -465.0
# 10th & K St NW                                35.0
# 10th & Monroe St NE                         1289.0
# 10th & Quincy St NE / Turkey Thicket Rec      -6.0
# 10th & Rhode Island Ave NE                    -1.0
# 10th & U St NW                                25.0
# 10th St & Constitution Ave NW              -2699.0
# 10th St & Florida Ave NW                     374.0
# 10th St & L'Enfant Plaza SW                 -477.0
# 10th St & Rhode Island Ave NE                  9.0
# 10th St & Spring Rd NW                       220.0
# 11th & C St SE                               126.0
# 11th & Clifton St NW                        1219.0
# 11th & F St NW                             -2508.0
# 11th & Girard St NW                         4482.0
# 11th & H St NE                               -63.0
# 11th & Kenyon St NW                         9310.0
# Name: count, dtype: float64

# %%
# Convert the net_total Series to a DataFrame and name the column 'net_total'
stations = net_total.to_frame(name='net_total')

# Transform station names from the index to a column
stations.reset_index(inplace=True)

# Rename the 'index' column to 'station_name' for clarity
stations.rename(columns={'index': 'station_name'}, inplace=True)

# %%
# Drop duplicates to ensure one-to-one mapping for the merge
unique_stations = classic[['start_station_name', 'start_station_id', 'start_lat', 'start_lng']].drop_duplicates('start_station_name')

# Merge the unique stations with the 'stations' DataFrame based on the station name
stations = stations.merge(unique_stations, left_on='station_name', right_on='start_station_name', how='left')

# Now 'stations' has the additional columns merged based on matching station names
# Optionally, if you don't need the 'start_station_name' column anymore, you can drop it
# stations.drop('start_station_name', axis=1, inplace=True)

# %%
stations.drop('start_station_name', axis=1, inplace=True)

# %%
display(stations.isna().sum())
# Out:
# station_name        0
# net_total           0
# start_station_id    5
# start_lat           5
# start_lng           5
# dtype: int64

# %%
# Create a DataFrame of unique end stations from 'classic'
unique_end_stations = classic[['end_station_name', 'end_station_id', 'end_lat', 'end_lng']].drop_duplicates('end_station_name')

# Merge with 'stations' DataFrame where the 'start_station_id' is NaN
nan_stations = stations[stations['start_station_id'].isna()]
updated_nan_stations = nan_stations.merge(unique_end_stations, left_on='station_name', right_on='end_station_name', how='left')

# Now, updated_nan_stations contains the rows with NaN filled in from the 'end' columns where possible
# Rename the columns to match the 'stations' DataFrame
updated_nan_stations.drop(['start_station_id','start_lat','start_lng'], axis=1, inplace=True)
updated_nan_stations.rename(columns={
    'end_station_id': 'start_station_id',
    'end_lat': 'start_lat',
    'end_lng': 'start_lng'
}, inplace=True)

# Drop the unwanted 'end_station_name' column
updated_nan_stations.drop('end_station_name', axis=1, inplace=True)

# %%
# Now, let's update the stations DataFrame
nan_mask = stations['start_station_id'].isna()
for column in ['start_station_id', 'start_lat', 'start_lng']:
    # Use 'station_name' to align the updated data correctly
    stations.loc[nan_mask, column] = stations.loc[nan_mask, 'station_name'].map(updated_nan_stations.set_index('station_name')[column])

# %%
display(endstation_value_counts.head())
# Out:
# end_station_name
# New Hampshire Ave & T St NW        72098
# 15th & P St NW                     68783
# Columbus Circle / Union Station    66962
# 1st & M St NE                      60135
# Lincoln Memorial                   53400
# Name: count, dtype: int64

# %%
# Ensure the index of the Series is named 'station_name'
startstation_value_counts.index.name = 'station_name'
endstation_value_counts.index.name = 'station_name'

# Convert the Series to a DataFrame
start_counts_df = startstation_value_counts.reset_index().rename(columns={startstation_value_counts.name: 'start_count'})
end_counts_df = endstation_value_counts.reset_index().rename(columns={endstation_value_counts.name: 'end_count'})

# Merge with the 'stations' DataFrame on 'station_name'
stations = stations.merge(start_counts_df, on='station_name', how='left')
stations = stations.merge(end_counts_df, on='station_name', how='left')

# %%
display(stations.sample(15))
# Out:
#                             station_name  net_total start_station_id  \
# 51                     14th & Otis Pl NW     6485.0          31131.0
# 389  Four Mile Run Dr & S Walter Reed Dr      -40.0          31059.0
# 513           Mandeville Ln & Stovall St       -7.0          31974.0
# 143                       23rd & M St NW    -6393.0          31128.0
# 262                Barton St & 10th St N      526.0          31050.0
# 127                20th & Columbia Rd NW     6625.0          31133.0
# 98         18th St & Pennsylvania Ave NW    -1879.0          31242.0
# 215                        8th & D St NW    -3731.0          31270.0
# 138                       22nd & H St NW     -509.0          31127.0
# 607          Pennsylvania Ave & Park Ave      -63.0          32603.0
# 226                 9th & Ingraham St NW       56.0          31424.0
# 224              8th Rd & S Frederick St       50.0          31951.0
# 151   2nd & V St SW / James Creek Marina     -602.0          31667.0
# 457                Key Blvd & N Quinn St        5.0          31027.0
# 135                    21st St & G st NW     -175.0          31328.0
#
#      start_lat  start_lng  start_count  end_count
# 51   38.934405 -77.032687      16794.0    10309.0
# 389  38.847360 -77.095431       1456.0     1496.0
# 513  38.802893 -77.072558        522.0      529.0
# 143  38.905303 -77.050264      33829.0    40222.0
# 262  38.884961 -77.087770       1663.0     1137.0
# 127  38.918036 -77.045487      18926.0    12301.0
# 98   38.899680 -77.041539      15490.0    17369.0
# 215  38.894851 -77.023240      16989.0    20720.0
# 138  38.898925 -77.048852      16873.0    17382.0
# 607  38.887403 -77.176992        691.0      754.0
# 226  38.953663 -77.025613        625.0      569.0
# 224  38.857049 -77.116339        274.0      224.0
# 151  38.863743 -77.013814       6374.0     6976.0
# 457  38.896355 -77.078408         32.0       27.0
# 135  38.898308 -77.046402      25940.0    26115.0

# %%
stations['start_count'].fillna(0, inplace=True)
stations['end_count'].fillna(0, inplace=True)

# %%
display(classic.sample(5))
# Out:
#                   ride_id          started_at            ended_at  \
# 5788815  CCCBB35292A03C2E 2022-10-31 15:40:50 2022-10-31 15:45:42
# 2728148  BFFFF33AB8894184 2021-12-27 13:47:41 2021-12-27 14:05:14
# 7755592  88B35904847C6F0D 2023-06-01 13:52:33 2023-06-01 14:19:15
# 1831190  11668CF8889D9B75 2021-09-15 16:48:27 2021-09-15 17:11:51
# 2313781  7A2C789DB69796C0 2021-10-31 16:40:38 2021-10-31 16:50:39
#
#                          start_station_name start_station_id  \
# 5788815                      11th & O St NW          31286.0
# 2728148  New Jersey Ave & N St NW/Dunbar HS          31636.0
# 7755592   Ward Circle / American University          31301.0
# 1831190                       4th & W St NE          31500.0
# 2313781                       7th & K St NW          31653.0
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# 5788815               11th & M St NW        31266.0  38.908430 -77.027140
# 2728148  New York Ave & Hecht Ave NE        31518.0  38.907333 -77.015360
# 7755592                8th & O St NW        31281.0  38.938736 -77.087171
# 1831190             4th St & G St SW        31666.0  38.919077 -77.000648
# 2313781                6th & K St NE        31645.0  38.902674 -77.021392
#
#            end_lat    end_lng member_casual  weekend  morning
# 5788815  38.905578 -77.027313        member    False    False
# 2728148  38.915604 -76.983683        member    False     True
# 7755592  38.908640 -77.022770        member    False     True
# 1831190  38.881123 -77.017658        member    False    False
# 2313781  38.902932 -76.998405        member     True    False

# %%
# Filter for AM: 'weekend' is False and 'morning' is True
am_filter = (classic['weekend'] == False) & (classic['morning'] == True)
# Filter for PM: 'weekend' is False and 'morning' is False
pm_filter = (classic['weekend'] == False) & (classic['morning'] == False)

# Count the start stations for AM and PM
weekday_am_startstation_value_counts = classic.loc[am_filter, 'start_station_name'].value_counts()
weekday_pm_startstation_value_counts = classic.loc[pm_filter, 'start_station_name'].value_counts()

# Count the end stations for AM and PM
weekday_am_endstation_value_counts = classic.loc[am_filter, 'end_station_name'].value_counts()
weekday_pm_endstation_value_counts = classic.loc[pm_filter, 'end_station_name'].value_counts()

# Calculate the net total for each station for AM and PM
weekday_am_net = weekday_am_startstation_value_counts.subtract(weekday_am_endstation_value_counts, fill_value=0)
weekday_pm_net = weekday_pm_startstation_value_counts.subtract(weekday_pm_endstation_value_counts, fill_value=0)

# %%
display(weekday_am_net.head())
# Out:
# 10th & E St NW          -5271.0
# 10th & Florida Ave NW    1835.0
# 10th & G St NW          -4862.0
# 10th & H St NE           1815.0
# 10th & K St NW          -2160.0
# Name: count, dtype: float64

# %%
# Ensure the index of the Series is named 'station_name'
weekday_am_net.index.name = 'station_name'
weekday_pm_net.index.name = 'station_name'

# Convert the Series to a DataFrame
weekday_am_df = weekday_am_net.reset_index().rename(columns={weekday_am_net.name: 'weekday_am_net'})
weekday_pm_df = weekday_pm_net.reset_index().rename(columns={weekday_pm_net.name: 'weekday_pm_net'})

# Merge with the 'stations' DataFrame on 'station_name'
stations = stations.merge(weekday_am_df, on='station_name', how='left')
stations = stations.merge(weekday_pm_df, on='station_name', how='left')

# %%
display(stations.sample(5))
# Out:
#                        station_name  net_total start_station_id  start_lat  \
# 718                    Takoma Metro      602.0          31408.0  38.975219
# 472  L'Enfant Plaza / 7th & C St SW     -225.0          31218.0  38.886266
# 592   North Village and Park Garden       -1.0          32256.0  38.983199
# 398         Garland Ave & Walden Rd      -28.0          32082.0  39.000480
# 450  Kenilworth Terr & Hayes St. NE        5.0          31717.0  38.900468
#
#      start_lng  start_count  end_count  weekday_am_net  weekday_pm_net
# 718 -77.016855       5777.0     5175.0         -1278.0          1688.0
# 472 -77.022241      15112.0    15337.0         -1097.0          1235.0
# 592 -77.341823        108.0      109.0             1.0            -2.0
# 398 -77.000770        441.0      469.0            50.0           -72.0
# 450 -76.947287        198.0      193.0            14.0           -10.0

# %%
# Filter for AM: 'weekend' is False and 'morning' is True
fun_am_filter = (classic['weekend'] == True) & (classic['morning'] == True)
# Filter for PM: 'weekend' is False and 'morning' is False
fun_pm_filter = (classic['weekend'] == True) & (classic['morning'] == False)

# Count the start stations for AM and PM
fun_am_startstation_value_counts = classic.loc[fun_am_filter, 'start_station_name'].value_counts()
fun_pm_startstation_value_counts = classic.loc[fun_pm_filter, 'start_station_name'].value_counts()

# Count the end stations for AM and PM
fun_am_endstation_value_counts = classic.loc[fun_am_filter, 'end_station_name'].value_counts()
fun_pm_endstation_value_counts = classic.loc[fun_pm_filter, 'end_station_name'].value_counts()

# Calculate the net total for each station for AM and PM
fun_am_net = fun_am_startstation_value_counts.subtract(fun_am_endstation_value_counts, fill_value=0)
fun_pm_net = fun_pm_startstation_value_counts.subtract(fun_pm_endstation_value_counts, fill_value=0)

# %%
# Ensure the index of the Series is named 'station_name'
fun_am_net.index.name = 'station_name'
fun_pm_net.index.name = 'station_name'

# Convert the Series to a DataFrame
fun_am_df = fun_am_net.reset_index().rename(columns={fun_am_net.name: 'fun_am_net'})
fun_pm_df = fun_pm_net.reset_index().rename(columns={fun_pm_net.name: 'fun_pm_net'})

# Merge with the 'stations' DataFrame on 'station_name'
stations = stations.merge(fun_am_df, on='station_name', how='left')
stations = stations.merge(fun_pm_df, on='station_name', how='left')

# %%
print(stations.columns)
# Out:
# Index(['station_name', 'net_total', 'start_station_id', 'start_lat',
#        'start_lng', 'start_count', 'end_count', 'weekday_am_net',
#        'weekday_pm_net', 'fun_am_net', 'fun_pm_net'],
#       dtype='object')

# %%
stations = stations.reindex(columns=['station_name','start_count', 'end_count', 'net_total', 'weekday_am_net',
       'weekday_pm_net', 'fun_am_net', 'fun_pm_net', 'start_station_id', 'start_lat',
       'start_lng'])
display(stations.sample(5))
# Out:
#                         station_name  start_count  end_count  net_total  \
# 370  Fallsgrove Blvd & Fallsgrove Dr        361.0      360.0        1.0
# 187                    4th & M St SE      17422.0    21274.0    -3852.0
# 48                    14th & L St NW      21482.0    21976.0     -494.0
# 173               3rd & Tingey St SE      16236.0    18748.0    -2512.0
# 75              15th St & N Scott St       4101.0     3435.0      666.0
#
#      weekday_am_net  weekday_pm_net  fun_am_net  fun_pm_net start_station_id  \
# 370            34.0           -34.0         3.0        -2.0          32004.0
# 187         -3755.0          1234.0     -1001.0      -330.0          31652.0
# 48          -2835.0          2193.0       415.0      -267.0          31283.0
# 173         -1074.0          -854.0      -554.0       -30.0          31634.0
# 75            872.0          -386.0       247.0       -67.0          31031.0
#
#      start_lat  start_lng
# 370  39.096312 -77.192672
# 187  38.876751 -77.000736
# 48   38.903658 -77.031737
# 173  38.875010 -77.002400
# 75   38.890540 -77.080950

# %%
stations['weekday_am_net'] = stations['weekday_am_net'] * -1
stations['weekday_pm_net'] = stations['weekday_pm_net'] * -1
stations['fun_am_net'] = stations['fun_am_net'] * -1
stations['fun_pm_net'] = stations['fun_pm_net'] * -1

# %%
stations['net_total'] = stations['net_total'] * -1

# %%
stations = stations.fillna(0)

# %%
copy_stations = stations.copy()

# %%
display(stations.sample(10))
# Out:
#                                    station_name  start_count  end_count  \
# 232             American University East Campus       4978.0     2650.0
# 272                     Braddock Rd Metro North       2172.0     2017.0
# 305                 Columbia Pike & S Taylor St        202.0      216.0
# 421                 Green Range Dr and Glade Dr        113.0      117.0
# 654                    Riggs Rd & East West Hwy        334.0      368.0
# 775           Washington Blvd & Walter Reed Dr        1973.0     2040.0
# 446     Jones Branch Drive & Scotts Crossing Rd        143.0      149.0
# 140                              22nd & P ST NW      27795.0    28857.0
# 609  Pentagon City Metro / 12th St & S Hayes St       9516.0     9942.0
# 724                  The Mall at Prince Georges       1681.0     1698.0
#
#      net_total  weekday_am_net  weekday_pm_net  fun_am_net  fun_pm_net  \
# 232    -2328.0          -441.0         -1336.0      -222.0      -329.0
# 272     -155.0            84.0          -135.0       -19.0       -85.0
# 305       14.0           -15.0             6.0        -2.0        25.0
# 421        4.0            -7.0             9.0        -3.0         5.0
# 654       34.0            -8.0            38.0        -0.0         4.0
# 775       67.0          -162.0           192.0       -66.0       103.0
# 446        6.0            30.0           -23.0       -10.0         9.0
# 140     1062.0         -1893.0          2328.0       157.0       470.0
# 609      426.0          1843.0         -1411.0       277.0      -283.0
# 724       17.0           129.0          -159.0        50.0        -3.0
#
#     start_station_id  start_lat  start_lng
# 232          31320.0  38.936298 -77.087128
# 272          31047.0  38.814577 -77.052808
# 305          31923.0  38.858524 -77.103728
# 421          32249.0  38.939617 -77.366786
# 654          32414.0  38.972500 -76.980700
# 775          31073.0  38.873219 -77.082104
# 446          32233.0  38.928502 -77.215624
# 140          31285.0  38.909394 -77.048728
# 609          31005.0  38.862303 -77.059936
# 724          32422.0  38.968842 -76.954171

# %%
display(stations.describe())
# Out:
#         start_count     end_count    net_total  weekday_am_net  \
# count    818.000000    818.000000   818.000000      818.000000
# mean    7527.639364   7506.815403   -20.823961       -5.522005
# std    11249.576289  11503.753886  1518.887457     2038.215296
# min        0.000000      0.000000 -9601.000000    -8397.000000
# 25%      470.000000    462.500000  -205.250000     -369.250000
# 50%     2218.000000   2068.000000    -5.500000      -19.000000
# 75%    10396.250000   9856.000000   119.000000       67.750000
# max    72868.000000  72098.000000  7480.000000    10130.000000
#
#        weekday_pm_net   fun_am_net   fun_pm_net   start_lat   start_lng
# 19       -789.0          31102.0  38.929464 -77.027822
# 604     -1038.0          31602.0  38.930800 -77.031500
# 47      -1145.0          31124.0  38.928552 -77.032224
# 308      -497.0          31115.0  38.928121 -77.023795
# 127      -371.0          31133.0  38.918036 -77.045487
# 51       -467.0          31131.0  38.934405 -77.032687
# 307      -632.0          31113.0  38.920669 -77.043680
# 814      -871.0          31323.0  38.923389 -77.051833
# 78       -516.0          31103.0  38.926088 -77.036536
# 50       -397.0          31649.0  38.931991 -77.032956
# 280      -483.0          31106.0  38.923203 -77.047637
# 101      -695.0          31114.0  38.918809 -77.041571
# 22       -438.0          31651.0  38.931322 -77.028247
# 229      -642.0          31104.0  38.922925 -77.042581
# 17          8.0          31126.0  38.925636 -77.027112
# 45        -15.0          31123.0  38.925284 -77.032375
# 726       622.0          31241.0  38.905900 -77.032500
# 474        70.0          31107.0  38.931900 -77.038800
# 79        -78.0          31122.0  38.928893 -77.036250

# %%
# Calculate the 'bike add ratio' column as described
stations['bike_add_ratio'] = np.where(
    (stations['start_count'] + stations['end_count']) != 0,  # avoid division by zero
    stations['end_count'] / (stations['start_count'] + stations['end_count']),
    0  # set unbalanced to 0 if there's no start or end count
)

# %%
stations['bike_add_ratio'] = (stations['bike_add_ratio'] * 100).round(1)

# %%
stations['daily_usage'] = ((stations['start_count'] + stations['end_count']) / 911).round(2)

# %%
display(stations.sort_values('start_count').tail(5))
# Out:
#                         station_name  start_count  end_count  net_total  \
# 197                    5th & K St NW      52301.0    53147.0      846.0
# 117                    1st & M St NE      59319.0    60135.0      816.0
# 311  Columbus Circle / Union Station      66037.0    66962.0      925.0
# 71                    15th & P St NW      67762.0    68783.0     1021.0
# 574      New Hampshire Ave & T St NW      72868.0    72098.0     -770.0
#
#      weekday_am_net  weekday_pm_net  fun_am_net  fun_pm_net start_station_id  \
# 197         -4578.0          5121.0      -784.0      1087.0          31600.0
# 117         -1776.0          2166.0      -667.0      1093.0          31603.0
# 311          5592.0         -3686.0      2183.0     -3164.0          31623.0
# 71          -2716.0          3835.0      -450.0       352.0          31201.0
# 574         -8397.0          8156.0     -1628.0      1099.0          31229.0
#
#      start_lat  start_lng  bike_add_ratio  daily_usage
# 197  38.903040 -77.019027            50.4       115.75
# 117  38.905697 -77.005483            50.3       131.12
# 311  38.896960 -77.004930            50.3       145.99
# 71   38.909868 -77.034421            50.4       149.88
# 574  38.915544 -77.038252            49.7       159.13

# %%
display(stations.sort_values('end_count').tail(5))
# Out:
#                         station_name  start_count  end_count  net_total  \
# 492                 Lincoln Memorial      50208.0    53400.0     3192.0
# 117                    1st & M St NE      59319.0    60135.0      816.0
# 311  Columbus Circle / Union Station      66037.0    66962.0      925.0
# 71                    15th & P St NW      67762.0    68783.0     1021.0
# 574      New Hampshire Ave & T St NW      72868.0    72098.0     -770.0
#
#      weekday_am_net  weekday_pm_net  fun_am_net  fun_pm_net start_station_id  \
# 492          1460.0           -49.0      2605.0      -824.0          31258.0
# 117         -1776.0          2166.0      -667.0      1093.0          31603.0
# 311          5592.0         -3686.0      2183.0     -3164.0          31623.0
# 71          -2716.0          3835.0      -450.0       352.0          31201.0
# 574         -8397.0          8156.0     -1628.0      1099.0          31229.0
#
#      start_lat  start_lng  bike_add_ratio  daily_usage
# 492  38.888255 -77.049436            51.5       113.73
# 117  38.905697 -77.005483            50.3       131.12
# 311  38.896960 -77.004930            50.3       145.99
# 71   38.909868 -77.034421            50.4       149.88
# 574  38.915544 -77.038252            49.7       159.13

# %%
display(stations.describe())
# Out:
#         start_count     end_count    net_total  weekday_am_net  \
# count    818.000000    818.000000   818.000000      818.000000
# mean    7527.639364   7506.815403   -20.823961       -5.522005
# std    11249.576289  11503.753886  1518.887457     2038.215296
# min        0.000000      0.000000 -9601.000000    -8397.000000
# 25%      470.000000    462.500000  -205.250000     -369.250000
# 50%     2218.000000   2068.000000    -5.500000      -19.000000
# 75%    10396.250000   9856.000000   119.000000       67.750000
# max    72868.000000  72098.000000  7480.000000    10130.000000
#
#        weekday_pm_net   fun_am_net   fun_pm_net   start_lat   start_lng  \
# count      818.000000   818.000000   818.000000  818.000000  818.000000
# mean        -8.035452    -3.189487    -4.077017   38.862490  -76.972713
# std       1571.600291   542.346813   362.816161    1.361834    2.696143
# min      -7229.000000 -2029.000000 -3618.000000    0.000000  -77.368416
# 25%       -141.750000   -99.750000   -39.500000   38.877863  -77.094861
# 50%          4.000000    -7.000000     1.000000   38.899957  -77.045064
# 75%        207.250000    16.000000    49.750000   38.932856  -77.011933
# max       8156.000000  3493.000000  1634.000000   39.125828    0.000000
#
#        bike_add_ratio  daily_usage
# count      818.000000   818.000000
# mean        49.153545    16.503142
# std          6.930896    24.922111
# min          0.000000     0.000000
# 25%         47.100000     1.017500
# 50%         49.800000     4.685000
# 75%         51.400000    22.895000
# max        100.000000   159.130000

# %%
display(stations.sort_values('net_total').head(20))
display(stations.sort_values('net_total').tail(20))
# Out:
#                                           station_name  start_count  \
# 296                           Columbia & Ontario Rd NW      28375.0
# 19                                 11th & Kenyon St NW      24474.0
# 604                            Park Rd & Holmead Pl NW      21308.0
# 47                                 14th & Irving St NW      32150.0
# 308                       Columbia Rd & Georgia Ave NW      16219.0
# 127                              20th & Columbia Rd NW      18926.0
# 51                                   14th & Otis Pl NW      16794.0
# 307                        Columbia Rd & Belmont St NW      19434.0
# 814  Woodley Park Metro / Calvert St & Connecticut ...      19783.0
# 78                                16th & Harvard St NW      12813.0
# 50                                 14th & Newton St NW      16233.0
# 280                           Calvert & Biltmore St NW      10738.0
# 101                           18th St & Wyoming Ave NW      36718.0
# 22                                   11th & Park Rd NW      17465.0
# 229                        Adams Mill & Columbia Rd NW      32641.0
# 17                                 11th & Girard St NW      21449.0
# 45                                 14th & Girard St NW      13335.0
# 726                                      Thomas Circle      44250.0
# 474                            Lamont & Mt Pleasant NW      22202.0
# 79                                 16th & Irving St NW      15237.0
#
# 2            31274.0  38.898243 -77.026235            57.4        38.21
# 439          31247.0  38.888553 -77.032427            52.8       105.30
# 620          31295.0  38.905368 -77.065149            55.6        54.10
# 520          31200.0  38.910100 -77.044400            52.7       110.70
# 527          31230.0  38.898364 -77.027869            55.4        63.94
# 143          31128.0  38.905303 -77.050264            54.3        81.29
# 402          31215.0  38.902314 -77.059141            57.8        48.08
# 727          31293.0  38.902826 -77.060173            61.9        31.78
# 278          31225.0  38.903750 -77.062690            59.4        43.82

# %%
display(stations.describe())
# Out:
#         start_count     end_count    net_total  weekday_am_net  \
# count    818.000000    818.000000   818.000000      818.000000
# mean    7527.639364   7506.815403   -20.823961       -5.522005
# std    11249.576289  11503.753886  1518.887457     2038.215296
# min        0.000000      0.000000 -9601.000000    -8397.000000
# 25%      470.000000    462.500000  -205.250000     -369.250000
# 50%     2218.000000   2068.000000    -5.500000      -19.000000
# 75%    10396.250000   9856.000000   119.000000       67.750000
# max    72868.000000  72098.000000  7480.000000    10130.000000
#
#        weekday_pm_net   fun_am_net   fun_pm_net   start_lat   start_lng  \
# count      818.000000   818.000000   818.000000  818.000000  818.000000
# mean        -8.035452    -3.189487    -4.077017   38.862490  -76.972713
# std       1571.600291   542.346813   362.816161    1.361834    2.696143
# min      -7229.000000 -2029.000000 -3618.000000    0.000000  -77.368416
# 25%       -141.750000   -99.750000   -39.500000   38.877863  -77.094861
# 50%          4.000000    -7.000000     1.000000   38.899957  -77.045064
# 75%        207.250000    16.000000    49.750000   38.932856  -77.011933
# max       8156.000000  3493.000000  1634.000000   39.125828    0.000000
#
#        bike_add_ratio  daily_usage
# count      818.000000   818.000000
# mean        49.153545    16.503142
# std          6.930896    24.922111
# min          0.000000     0.000000
# 25%         47.100000     1.017500
# 50%         49.800000     4.685000
# 75%         51.400000    22.895000
# max        100.000000   159.130000

# %%
no_end_station = classic[classic['end_station_name'].isnull()]

# %% [markdown]
# Changing net counts to per-day values

# %%
# Define the date range
start_date = pd.to_datetime('2021-01-01')
end_date = pd.to_datetime('2023-06-30')

# Generate a range of dates
daterange = pd.date_range(start_date, end_date)

# Count weekdays and weekend days
weekdays = ((daterange.dayofweek >= 0) & (daterange.dayofweek <= 4)).sum()
weekends = ((daterange.dayofweek == 5) | (daterange.dayofweek == 6)).sum()

# %%
# Overwrite the 'net' columns with per-day values, rounded to 2 decimal places
stations['weekday_am_net'] = (stations['weekday_am_net'] / weekdays).round(2)
stations['weekday_pm_net'] = (stations['weekday_pm_net'] / weekdays).round(2)
stations['fun_am_net'] = (stations['fun_am_net'] / weekends).round(2)
stations['fun_pm_net'] = (stations['fun_pm_net'] / weekends).round(2)

# %%
stations.rename({'bike_add_ratio': '%_bikes_added'}, axis='columns', inplace=True)

# %%
display(stations.columns)
# Out:
# Index(['station_name', 'start_count', 'end_count', 'net_total',
#        'weekday_am_net', 'weekday_pm_net', 'fun_am_net', 'fun_pm_net',
#        'start_station_id', 'start_lat', 'start_lng', '%_bikes_added',
#        'daily_usage'],
#       dtype='object')

# %%
stations = stations.reindex(columns=['station_name', 'start_count', 'end_count', 'net_total',
       'daily_usage', '%_bikes_added', 'weekday_am_net', 'weekday_pm_net', 'fun_am_net', 'fun_pm_net',
       'start_station_id', 'start_lat', 'start_lng'])

# %%
display(stations.sort_values('net_total').tail(1))
# Out:
#                        station_name  start_count  end_count  net_total  \
# 278  C & O Canal & Wisconsin Ave NW      16219.0    23699.0     7480.0
#
#      daily_usage  %_bikes_added  weekday_am_net  weekday_pm_net  fun_am_net  \
# 278        43.82           59.4            5.28            1.68        9.18
#
#      fun_pm_net start_station_id  start_lat  start_lng
# 278        2.17          31225.0   38.90375  -77.06269

# %%
import folium

# %%
# Create the base map
m = folium.Map(location=[38.888255,	-77.049436], zoom_start=13)

# Function to create popup text
def create_popup(row):
    return (f"{row['station_name']}<br>"
            f"Daily usage: {row['daily_usage']:.2f}<br>"
            f"% bikes added: {row['%_bikes_added']:.2f}<br>"
            f"Work am: {row['weekday_am_net']}<br>"
            f"Work pm: {row['weekday_pm_net']}<br>"
            f"Fun am: {row['fun_am_net']}<br>"
            f"Fun pm: {row['fun_pm_net']}")

# Stations with the lowest net totals - blue markers
for idx, row in stations.sort_values('net_total').head(25).iterrows():
    folium.Marker(
        location=[row['start_lat'], row['start_lng']],
        popup=folium.Popup(create_popup(row), max_width=300),
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Stations with the highest net totals - orange markers
for idx, row in stations.sort_values('net_total').tail(25).iterrows():
    folium.Marker(
        location=[row['start_lat'], row['start_lng']],
        popup=folium.Popup(create_popup(row), max_width=300),
        icon=folium.Icon(color='orange')
    ).add_to(m)

# %% [markdown]
# Add top 4 stations for daily usage to map

# %%
# Function to create popup text
def create_popup(row):
    return (f"{row['station_name']}<br>"
            f"Daily usage: {row['daily_usage']:.2f}<br>"
            f"% bikes added: {row['%_bikes_added']:.2f}<br>"
            f"Work am: {row['weekday_am_net']}<br>"
            f"Work pm: {row['weekday_pm_net']}<br>"
            f"Fun am: {row['fun_am_net']}<br>"
            f"Fun pm: {row['fun_pm_net']}")

# Stations with the highest daily usage - green markers
for idx, row in stations.sort_values('start_count').tail(4).iterrows():
    folium.Marker(
        location=[row['start_lat'], row['start_lng']],
        popup=folium.Popup(create_popup(row), max_width=300),
        icon=folium.Icon(color='green')
    ).add_to(m)

# %%
# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2487908eb599e0f4d1a4a0da737c3510 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2487908eb599e0f4d1a4a0da737c3510&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2487908eb599e0f4d1a4a0da737c3510 = L.map(
#                 &quot;map_2487908eb599e0f4d1a4a0da737c3510&quot;,
#                 {
#                     center: [38.888255, -77.049436],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5db6bcde45244298bc6dde2f39965f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2487908eb599e0f4d1a4a0da737c3510);
#
#
#             var marker_9f1e3d26635454a30e5eb6fc6f07c55a = L.marker(
#                 [38.924088, -77.040787],
#                 {}
#             ).addTo(map_2487908eb599e0f4d1a4a0da737c3510);
#
#
#             var icon_9853b318760e47d70b8bb0e2a2a3bd60 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9f1e3d26635454a30e5eb6fc6f07c55a.setIcon(icon_9853b318760e47d70b8bb0e2a2a3bd60);
#
#
#         var popup_d20437a831f7c78893dc5a5b189727e1 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_11092be075ba6dd785fe25eaa3e393d0 = $(`&lt;div id=&quot;html_11092be075ba6dd785fe25eaa3e393d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Columbia &amp; Ontario Rd NW&lt;br&gt;Daily usage: 51.76&lt;br&gt;% bikes added: 39.80&lt;br&gt;Work am: -8.58&lt;br&gt;Work pm: -2.18&lt;br&gt;Fun am: -6.43&lt;br&gt;Fun pm: -3.55&lt;/div&gt;`)[0];
#                 popup_d20437a831f7c78893dc5a5b189727e1.setContent(html_11092be075ba6dd785fe25eaa3e393d0);
#
#
#
#         marker_9f1e3d26635454a30e5eb6fc6f07c55a.bindPopup(popup_d20437a831f7c78893dc5a5b189727e1)
#         ;
#
#
#
#
#             var marker_a3c906c9d6939c4fd78d56477b5b5826 = L.marker(
#                 [38.929464, -77.027822],
#                 {}
#             ).addTo(map_2487908eb599e0f4d1a4a0da737c3510);
#
#
#             var icon_0d57dc3d03454ad9aafea536b7a891b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a3c906c9d6939c4fd78d56477b5b5826.setIcon(icon_0d57dc3d03454ad9aafea536b7a891b5);
#
#
#         var popup_4a281fdd4aee2bf47bd9d5d0fbe1938d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_5a8c3d8b3d31bc795d126a1318c7959f = $(`&lt;div id=&quot;html_5a8c3d8b3d31bc795d126a1318c7959f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11th &amp; Kenyon St NW&lt;br&gt;Daily usage: 43.51&lt;br&gt;% bikes added: 38.30&lt;br&gt;Work am: -8.12&lt;br&gt;Work pm: -1.98&lt;br&gt;Fun am: -7.48&lt;br&gt;Fun pm: -3.03&lt;/div&gt;`)[0];
#                 popup_4a281fdd4aee2bf47bd9d5d0fbe1938d.setContent(html_5a8c3d8b3d31bc795d126a1318c7959f);
#
#
#
#         marker_a3c906c9d6939c4fd78d56477b5b5826.bindPopup(popup_4a281fdd4aee2bf47bd9d5d0fbe1938d)
#         ;
#
#
#
#
#             var marker_2d74b5977060d946da41556d606761de = L.marker(
#                 [38.9308, -77.0315],
#                 {}
#             ).addTo(map_2487908eb599e0f4d1a4a0da737c3510);
#
#
#             var icon_558453abf977fbed5d05db9e09d89f51 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2d74b5977060d946da41556d606761de.setIcon(icon_558453abf977fbed5d05db9e09d89f51);
#
#
#         var popup_15b2fbe91fd9297501ade614f4330396 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_7c887993bba269db55367eafe4a4b341 = $(`&lt;div id=&quot;html_7c887993bba269db55367eafe4a4b341&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Park Rd &amp; Holmead Pl NW&lt;br&gt;Daily usage: 37.53&lt;br&gt;% bikes added: 37.70&lt;br&gt;Work am: -5.94&lt;br&gt;Work pm: -3.22&lt;br&gt;Fun am: -5.49&lt;br&gt;Fun pm: -3.99&lt;/div&gt;`)[0];
#                 popup_15b2fbe91fd9297501ade614f4330396.setContent(html_7c887993bba269db55367eafe4a4b341);
#
#
#
#         marker_2d74b5977060d946da41556d606761

# %%
m.save('map.html')
