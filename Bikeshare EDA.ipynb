# %%
import pandas as pd

# %%
dweather = pd.read_csv('C:\\Asus WebStorage\\psabin@gmail.com\\MySyncFolder\\Data Science Course\\Used CSVs\\CSB_2021-2023_Daily_Weather.csv')
hweather = pd.read_csv('C:\\Asus WebStorage\\psabin@gmail.com\\MySyncFolder\\Data Science Course\\Used CSVs\\CSB_2021-2023_Hourly_Weather.csv')

# %%
display(dweather.head())
display(hweather.head())
# Out:
#          Date  Casual  Member  Total_rides  weathercode (wmo code)  \
# 0  2021-01-01     371     590          961                      63
# 1  2021-01-02    2874    2844         5718                      61
# 2  2021-01-03     495    1133         1628                      63
# 3  2021-01-04     907    2074         2981                       3
# 4  2021-01-05    1057    2004         3061                      51
#
#    temperature_2m_mean (°C)  apparent_temperature_mean (°C)  \
# 0                       2.3                            -0.9
# 1                       7.6                             4.8
# 2                       3.9                             0.9
# 3                       4.1                             1.0
# 4                       4.0                             1.4
#
#    windspeed_10m_max (km/h)
# 0                      10.6
# 1                      19.1
# 2                      13.0
# 3                      13.3
# 4                       9.2
#          Date  Hour  Casual  Member  Total_rides  temperature_2m (°C)  \
# 0  2021-01-01     0    20.0    26.0         46.0                  2.4
# 1  2021-01-01     1    23.0    23.0         46.0                  1.8
# 2  2021-01-01     2    20.0    28.0         48.0                  1.1
# 3  2021-01-01     3     9.0     7.0         16.0                  1.6
# 4  2021-01-01     4     7.0     5.0         12.0                  1.6
#
#    relativehumidity_2m (%)  weathercode (wmo code)  windspeed_10m (km/h)
# 0                       90                       1                  10.2
# 1                       88                       1                  10.0
# 2                       87                       2                  10.1
# 3                       81                       2                  10.6
# 4                       77                       2                   9.9

# %%
display(hweather.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21864 entries, 0 to 21863
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          21864 non-null  datetime64[ns]
#  1   hour          21864 non-null  int64
#  2   casual        21864 non-null  float64
#  3   member        21853 non-null  float64
#  4   total_rides   21853 non-null  float64
#  5   temperature   21864 non-null  float64
#  6   rel_humidity  21864 non-null  int64
#  7   weather_code  21864 non-null  int64
#  8   wind_speed    21864 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(3)
# memory usage: 1.5 MB
# None

# %%
display(dweather.describe())
display(hweather.describe())
# Out:
#              Casual        Member   Total_rides  weathercode (wmo code)  \
# count    911.000000    911.000000    911.000000              911.000000
# mean    3607.552141   5372.278814   8979.830955               28.105379
# std     2087.382795   2046.922096   3778.061891               28.319602
# min      174.000000    323.000000    497.000000                0.000000
# 25%     1909.500000   3908.000000   6240.500000                2.000000
# 50%     3336.000000   5411.000000   8991.000000                3.000000
# 75%     5004.000000   6843.500000  11926.500000               55.000000
# max    12839.000000  10657.000000  19531.000000               75.000000
#
#        temperature_2m_mean (°C)  apparent_temperature_mean (°C)  \
# count                911.000000                      911.000000
# mean                  14.019868                       12.792536
# std                    8.953601                       11.632842
# min                   -9.100000                      -15.200000
# 25%                    6.600000                        2.900000
# 50%                   14.300000                       12.500000
# 75%                   22.000000                       22.800000
# max                   30.100000                       34.700000
#
#        windspeed_10m_max (km/h)
# count                911.000000
# mean                  15.684852
# std                    5.444250
# min                    5.600000
# 25%                   11.700000
# 50%                   14.500000
# 75%                   18.900000
# max                   36.700000
#                Hour        Casual        Member   Total_rides  \
# count  21864.000000  21853.000000  21853.000000  21853.000000
# mean      11.500000    150.390335    223.957626    374.347961
# std        6.922345    162.049422    200.588576    343.928606
# min        0.000000      0.000000      0.000000      1.000000
# 25%        5.750000     26.000000     50.000000     78.000000
# 50%       11.500000     95.000000    186.000000    292.000000
# 75%       17.250000    220.000000    341.000000    568.000000
# max       23.000000   1206.000000   1264.000000   1965.000000
#
#        temperature_2m (°C)  relativehumidity_2m (%)  weathercode (wmo code)  \
# count         21864.000000             21864.000000            21864.000000
# mean             14.021030                68.338685                8.489984
# std               9.581512                19.529426               18.955336
# min             -12.800000                19.000000                0.000000
# 25%               6.200000                52.000000                0.000000
# 50%              14.300000                69.000000                1.000000
# 75%              22.000000                85.000000                3.000000
# max              36.400000               100.000000               75.000000
#
#        windspeed_10m (km/h)
# count          21864.000000
# mean              10.267755
# std                5.106673
# min                0.000000
# 25%                6.800000
# 50%                9.300000
# 75%               12.900000
# max               36.700000

# %%
display(hweather.isna().sum())
display(dweather.isna().sum())
# Out:
# Date                        0
# Hour                        0
# Casual                     11
# Member                     11
# Total_rides                11
# temperature_2m (°C)         0
# relativehumidity_2m (%)     0
# weathercode (wmo code)      0
# windspeed_10m (km/h)        0
# dtype: int64
# Date                              0
# Casual                            0
# Member                            0
# Total_rides                       0
# weathercode (wmo code)            0
# temperature_2m_mean (°C)          0
# apparent_temperature_mean (°C)    0
# windspeed_10m_max (km/h)          0
# dtype: int64

# %%
print(hweather.columns)
hweather.rename(columns={'Date': 'date', 'Hour': 'hour', 'Casual': 'casual', 'Member': 'member', 'Total_rides': 'total_rides',
       'temperature_2m (°C)': 'temperature', 'relativehumidity_2m (%)': 'rel_humidity',
       'weathercode (wmo code)': 'weather_code', 'windspeed_10m (km/h)': 'wind_speed'}, inplace=True)
display(hweather.head())
# Out:
# Index(['Date', 'Hour', 'Casual', 'Member', 'Total_rides',
#        'temperature_2m (°C)', 'relativehumidity_2m (%)',
#        'weathercode (wmo code)', 'windspeed_10m (km/h)'],
#       dtype='object')
#          date  hour  casual  member  total_rides  temperature  rel_humidity  \
# 0  2021-01-01     0    20.0    26.0         46.0          2.4            90
# 1  2021-01-01     1    23.0    23.0         46.0          1.8            88
# 2  2021-01-01     2    20.0    28.0         48.0          1.1            87
# 3  2021-01-01     3     9.0     7.0         16.0          1.6            81
# 4  2021-01-01     4     7.0     5.0         12.0          1.6            77
#
#    weather_code  wind_speed
# 0             1        10.2
# 1             1        10.0
# 2             2        10.1
# 3             2        10.6
# 4             2         9.9

# %%
dweather.rename(str.lower, axis='columns', inplace=True)
hweather.rename(str.lower, axis='columns', inplace=True)
display(dweather.head())
# Out:
#          date  casual  member  total_rides  weathercode (wmo code)  \
# 0  2021-01-01     371     590          961                      63
# 1  2021-01-02    2874    2844         5718                      61
# 2  2021-01-03     495    1133         1628                      63
# 3  2021-01-04     907    2074         2981                       3
# 4  2021-01-05    1057    2004         3061                      51
#
#    temperature_2m_mean (°c)  apparent_temperature_mean (°c)  \
# 0                       2.3                            -0.9
# 1                       7.6                             4.8
# 2                       3.9                             0.9
# 3                       4.1                             1.0
# 4                       4.0                             1.4
#
#    windspeed_10m_max (km/h)
# 0                      10.6
# 1                      19.1
# 2                      13.0
# 3                      13.3
# 4                       9.2

# %%
dweather.rename({'weathercode (wmo code)': 'weather_code', 'apparent_temperature_mean (°c)': 'apparent_temp', 'windspeed_10m_max (km/h)': 'wind speed'}, axis='columns', inplace=True)
display(dweather.head())
# Out:
#          date  casual  member  total_rides  weather_code  \
# 0  2021-01-01     371     590          961            63
# 1  2021-01-02    2874    2844         5718            61
# 2  2021-01-03     495    1133         1628            63
# 3  2021-01-04     907    2074         2981             3
# 4  2021-01-05    1057    2004         3061            51
#
#    temperature_2m_mean (°c)  apparent_temp  wind speed
# 0                       2.3           -0.9        10.6
# 1                       7.6            4.8        19.1
# 2                       3.9            0.9        13.0
# 3                       4.1            1.0        13.3
# 4                       4.0            1.4         9.2

# %%
dweather.rename({'temperature_2m_mean (°c)': 'mean_temp'}, axis='columns', inplace=True)
display(dweather.head())
# Out:
#          date  casual  member  total_rides  weather_code  mean_temp  \
# 0  2021-01-01     371     590          961            63        2.3
# 1  2021-01-02    2874    2844         5718            61        7.6
# 2  2021-01-03     495    1133         1628            63        3.9
# 3  2021-01-04     907    2074         2981             3        4.1
# 4  2021-01-05    1057    2004         3061            51        4.0
#
#    apparent_temp  wind speed
# 0           -0.9        10.6
# 1            4.8        19.1
# 2            0.9        13.0
# 3            1.0        13.3
# 4            1.4         9.2

# %%
dweather['date'] = pd.to_datetime(dweather['date'])
display(dweather.head())
# Out:
#         date  casual  member  total_rides  weather_code  mean_temp  \
# 0 2021-01-01     371     590          961            63        2.3
# 1 2021-01-02    2874    2844         5718            61        7.6
# 2 2021-01-03     495    1133         1628            63        3.9
# 3 2021-01-04     907    2074         2981             3        4.1
# 4 2021-01-05    1057    2004         3061            51        4.0
#
#    apparent_temp  wind speed
# 0           -0.9        10.6
# 1            4.8        19.1
# 2            0.9        13.0
# 3            1.0        13.3
# 4            1.4         9.2

# %%
hweather['date'] = pd.to_datetime(hweather['date'])
display(hweather.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21864 entries, 0 to 21863
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     21864 non-null  datetime64[ns]
#  1   hour                     21864 non-null  int64
#  2   casual                   21853 non-null  float64
#  3   member                   21853 non-null  float64
#  4   total_rides              21853 non-null  float64
#  5   temperature_2m (°c)      21864 non-null  float64
#  6   relativehumidity_2m (%)  21864 non-null  int64
#  7   weathercode (wmo code)   21864 non-null  int64
#  8   windspeed_10m (km/h)     21864 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(3)
# memory usage: 1.5 MB
# None

# %%
display(hweather.head())
# Out:
#         date  hour  casual  member  total_rides  temperature_2m (°c)  \
# 0 2021-01-01     0    20.0    26.0         46.0                  2.4
# 1 2021-01-01     1    23.0    23.0         46.0                  1.8
# 2 2021-01-01     2    20.0    28.0         48.0                  1.1
# 3 2021-01-01     3     9.0     7.0         16.0                  1.6
# 4 2021-01-01     4     7.0     5.0         12.0                  1.6
#
#    relativehumidity_2m (%)  weathercode (wmo code)  windspeed_10m (km/h)
# 0                       90                       1                  10.2
# 1                       88                       1                  10.0
# 2                       87                       2                  10.1
# 3                       81                       2                  10.6
# 4                       77                       2                   9.9

# %%
hweather.rename({'weathercode (wmo code)': 'weather_code', 'temperature_2m (°c)': 'temp', 'windspeed_10m (km/h)': 'wind speed', 'relativehumidity_2m (%)': 'rel_humid'}, axis='columns', inplace=True)
# Out:
#         date  casual  member  total_rides  weather_code  mean_temp  \
# 0 2021-01-01     371     590          961            63        2.3
# 1 2021-01-02    2874    2844         5718            61        7.6
# 2 2021-01-03     495    1133         1628            63        3.9
# 3 2021-01-04     907    2074         2981             3        4.1
# 4 2021-01-05    1057    2004         3061            51        4.0
#
#    apparent_temp  wind speed
# 0           -0.9        10.6
# 1            4.8        19.1
# 2            0.9        13.0
# 3            1.0        13.3
# 4            1.4         9.2

# %%
display(hweather.head())
# Out:
#         date  hour  casual  member  total_rides  temp  rel_humid  \
# 0 2021-01-01     0    20.0    26.0         46.0   2.4         90
# 1 2021-01-01     1    23.0    23.0         46.0   1.8         88
# 2 2021-01-01     2    20.0    28.0         48.0   1.1         87
# 3 2021-01-01     3     9.0     7.0         16.0   1.6         81
# 4 2021-01-01     4     7.0     5.0         12.0   1.6         77
#
#    weather_code  wind speed
# 0             1        10.2
# 1             1        10.0
# 2             2        10.1
# 3             2        10.6
# 4             2         9.9

# %%
copy_dweather = dweather.copy()
copy_hweather = hweather.copy()

# %%
display(hweather.tail(15))
# Out:
#             date  hour  casual  member  total_rides  temp  rel_humid  \
# 21849 2023-06-30    20   272.0   412.0        684.0  23.6         92
# 21850 2023-06-30    21   247.0   324.0        571.0  22.9         92
# 21851 2023-06-30    22   172.0   266.0        438.0  22.5         93
# 21852 2023-06-30    23   177.0   223.0        400.0  22.1         93
# 21853 2021-01-21     3     NaN     NaN          NaN  -3.1         73
# 21854 2021-01-22     3     NaN     NaN          NaN   0.4         71
# 21855 2021-02-02     3     NaN     NaN          NaN   0.3         86
# 21856 2021-02-03     2     NaN     NaN          NaN  -1.2         71
# 21857 2021-02-09     1     NaN     NaN          NaN  -4.0         82
# 21858 2021-02-19     2     NaN     NaN          NaN  -1.1         94
# 21859 2021-02-19     3     NaN     NaN          NaN  -1.6         93
# 21860 2021-03-14     2     NaN     NaN          NaN   2.9         56
# 21861 2022-01-04     2     NaN     NaN          NaN  -8.7         77
# 21862 2022-03-13     2     NaN     NaN          NaN  -5.1         50
# 21863 2023-03-12     2     NaN     NaN          NaN   0.9         72
#
#        weather_code  wind speed
# 21849             3         9.0
# 21850             3        10.5
# 21851             3        10.6
# 21852             1         9.9
# 21853             0         5.1
# 21854             0        11.2
# 21855            71        19.8
# 21856             3        20.6
# 21857             1         7.8
# 21858            71        10.9
# 21859            51        10.4
# 21860             0        13.9
# 21861             0        10.1
# 21862             0        21.1
# 21863             0         6.4

# %%
hweather['member'] = hweather['member'].fillna(0)
hweather['total_rides'] = hweather['total_rides'].fillna(0)
hweather['casual'] = hweather['casual'].fillna(0)
display(hweather.tail(15))
# Out:
#             date  hour  casual  member  total_rides  temp  rel_humid  \
# 21849 2023-06-30    20   272.0   412.0        684.0  23.6         92
# 21850 2023-06-30    21   247.0   324.0        571.0  22.9         92
# 21851 2023-06-30    22   172.0   266.0        438.0  22.5         93
# 21852 2023-06-30    23   177.0   223.0        400.0  22.1         93
# 21853 2021-01-21     3     0.0     0.0          0.0  -3.1         73
# 21854 2021-01-22     3     0.0     0.0          0.0   0.4         71
# 21855 2021-02-02     3     0.0     0.0          0.0   0.3         86
# 21856 2021-02-03     2     0.0     0.0          0.0  -1.2         71
# 21857 2021-02-09     1     0.0     0.0          0.0  -4.0         82
# 21858 2021-02-19     2     0.0     0.0          0.0  -1.1         94
# 21859 2021-02-19     3     0.0     0.0          0.0  -1.6         93
# 21860 2021-03-14     2     0.0     0.0          0.0   2.9         56
# 21861 2022-01-04     2     0.0     0.0          0.0  -8.7         77
# 21862 2022-03-13     2     0.0     0.0          0.0  -5.1         50
# 21863 2023-03-12     2     0.0     0.0          0.0   0.9         72
#
#        weather_code  wind speed
# 21849             3         9.0
# 21850             3        10.5
# 21851             3        10.6
# 21852             1         9.9
# 21853             0         5.1
# 21854             0        11.2
# 21855            71        19.8
# 21856             3        20.6
# 21857             1         7.8
# 21858            71        10.9
# 21859            51        10.4
# 21860             0        13.9
# 21861             0        10.1
# 21862             0        21.1
# 21863             0         6.4

# %%
display(dweather['weather_code'].value_counts())
display(hweather['weather_code'].value_counts())
# Out:
# weather_code
# 3     186
# 1     145
# 51    130
# 2     102
# 63     87
# 61     80
# 53     60
# 0      51
# 55     28
# 73     14
# 65     10
# 71      9
# 75      9
# Name: count, dtype: int64
# weather_code
# 0     8581
# 1     5057
# 3     3094
# 2     2122
# 51    1362
# 53     598
# 61     399
# 63     222
# 55     193
# 71     101
# 73      90
# 75      28
# 65      17
# Name: count, dtype: int64

# %%
day_weather = dweather.copy()
hour_weather = hweather.copy()

# %%
json_data = {
	"0":{
		"day":{
			"description":"Sunny",
			"image":"http://openweathermap.org/img/wn/01d@2x.png"
		},
		"night":{
			"description":"Clear",
			"image":"http://openweathermap.org/img/wn/01n@2x.png"
		}
	},
	"1":{
		"day":{
			"description":"Mainly Sunny",
			"image":"http://openweathermap.org/img/wn/01d@2x.png"
		},
		"night":{
			"description":"Mainly Clear",
			"image":"http://openweathermap.org/img/wn/01n@2x.png"
		}
	},
	"2":{
		"day":{
			"description":"Partly Cloudy",
			"image":"http://openweathermap.org/img/wn/02d@2x.png"
		},
		"night":{
			"description":"Partly Cloudy",
			"image":"http://openweathermap.org/img/wn/02n@2x.png"
		}
	},
	"3":{
		"day":{
			"description":"Cloudy",
			"image":"http://openweathermap.org/img/wn/03d@2x.png"
		},
		"night":{
			"description":"Cloudy",
			"image":"http://openweathermap.org/img/wn/03n@2x.png"
		}
	},
	"45":{
		"day":{
			"description":"Foggy",
			"image":"http://openweathermap.org/img/wn/50d@2x.png"
		},
		"night":{
			"description":"Foggy",
			"image":"http://openweathermap.org/img/wn/50n@2x.png"
		}
	},
	"48":{
		"day":{
			"description":"Rime Fog",
			"image":"http://openweathermap.org/img/wn/50d@2x.png"
		},
		"night":{
			"description":"Rime Fog",
			"image":"http://openweathermap.org/img/wn/50n@2x.png"
		}
	},
	"51":{
		"day":{
			"description":"Light Drizzle",
			"image":"http://openweathermap.org/img/wn/09d@2x.png"
		},
		"night":{
			"description":"Light Drizzle",
			"image":"http://openweathermap.org/img/wn/09n@2x.png"
		}
	},
	"53":{
		"day":{
			"description":"Drizzle",
			"image":"http://openweathermap.org/img/wn/09d@2x.png"
		},
		"night":{
			"description":"Drizzle",
			"image":"http://openweathermap.org/img/wn/09n@2x.png"
		}
	},
	"55":{
		"day":{
			"description":"Heavy Drizzle",
			"image":"http://openweathermap.org/img/wn/09d@2x.png"
		},
		"night":{
			"description":"Heavy Drizzle",
			"image":"http://openweathermap.org/img/wn/09n@2x.png"
		}
	},
	"56":{
		"day":{
			"description":"Light Freezing Drizzle",
			"image":"http://openweathermap.org/img/wn/09d@2x.png"
		},
		"night":{
			"description":"Light Freezing Drizzle",
			"image":"http://openweathermap.org/img/wn/09n@2x.png"
		}
	},
	"57":{
		"day":{
			"description":"Freezing Drizzle",
			"image":"http://openweathermap.org/img/wn/09d@2x.png"
		},
		"night":{
			"description":"Freezing Drizzle",
			"image":"http://openweathermap.org/img/wn/09n@2x.png"
		}
	},
	"61":{
		"day":{
			"description":"Light Rain",
			"image":"http://openweathermap.org/img/wn/10d@2x.png"
		},
		"night":{
			"description":"Light Rain",
			"image":"http://openweathermap.org/img/wn/10n@2x.png"
		}
	},
	"63":{
		"day":{
			"description":"Rain",
			"image":"http://openweathermap.org/img/wn/10d@2x.png"
		},
		"night":{
			"description":"Rain",
			"image":"http://openweathermap.org/img/wn/10n@2x.png"
		}
	},
	"65":{
		"day":{
			"description":"Heavy Rain",
			"image":"http://openweathermap.org/img/wn/10d@2x.png"
		},
		"night":{
			"description":"Heavy Rain",
			"image":"http://openweathermap.org/img/wn/10n@2x.png"
		}
	},
	"66":{
		"day":{
			"description":"Light Freezing Rain",
			"image":"http://openweathermap.org/img/wn/10d@2x.png"
		},
		"night":{
			"description":"Light Freezing Rain",
			"image":"http://openweathermap.org/img/wn/10n@2x.png"
		}
	},
	"67":{
		"day":{
			"description":"Freezing Rain",
			"image":"http://openweathermap.org/img/wn/10d@2x.png"
		},
		"night":{
			"description":"Freezing Rain",
			"image":"http://openweathermap.org/img/wn/10n@2x.png"
		}
	},
	"71":{
		"day":{
			"description":"Light Snow",
			"image":"http://openweathermap.org/img/wn/13d@2x.png"
		},
		"night":{
			"description":"Light Snow",
			"image":"http://openweathermap.org/img/wn/13n@2x.png"
		}
	},
	"73":{
		"day":{
			"description":"Snow",
			"image":"http://openweathermap.org/img/wn/13d@2x.png"
		},
		"night":{
			"description":"Snow",
			"image":"http://openweathermap.org/img/wn/13n@2x.png"
		}
	},
	"75":{
		"day":{
			"description":"Heavy Snow",
			"image":"http://openweathermap.org/img/wn/13d@2x.png"
		},
		"night":{
			"description":"Heavy Snow",
			"image":"http://openweathermap.org/img/wn/13n@2x.png"
		}
	},
	"77":{
		"day":{
			"description":"Snow Grains",
			"image":"http://openweathermap.org/img/wn/13d@2x.png"
		},
		"night":{
			"description":"Snow Grains",
			"image":"http://openweathermap.org/img/wn/13n@2x.png"
		}
	},
	"80":{
		"day":{
			"description":"Light Showers",
			"image":"http://openweathermap.org/img/wn/09d@2x.png"
		},
		"night":{
			"description":"Light Showers",
			"image":"http://openweathermap.org/img/wn/09n@2x.png"
		}
	},
	"81":{
		"day":{
			"description":"Showers",
			"image":"http://openweathermap.org/img/wn/09d@2x.png"
		},
		"night":{
			"description":"Showers",
			"image":"http://openweathermap.org/img/wn/09n@2x.png"
		}
	},
	"82":{
		"day":{
			"description":"Heavy Showers",
			"image":"http://openweathermap.org/img/wn/09d@2x.png"
		},
		"night":{
			"description":"Heavy Showers",
			"image":"http://openweathermap.org/img/wn/09n@2x.png"
		}
	},
	"85":{
		"day":{
			"description":"Light Snow Showers",
			"image":"http://openweathermap.org/img/wn/13d@2x.png"
		},
		"night":{
			"description":"Light Snow Showers",
			"image":"http://openweathermap.org/img/wn/13n@2x.png"
		}
	},
	"86":{
		"day":{
			"description":"Snow Showers",
			"image":"http://openweathermap.org/img/wn/13d@2x.png"
		},
		"night":{
			"description":"Snow Showers",
			"image":"http://openweathermap.org/img/wn/13n@2x.png"
		}
	},
	"95":{
		"day":{
			"description":"Thunderstorm",
			"image":"http://openweathermap.org/img/wn/11d@2x.png"
		},
		"night":{
			"description":"Thunderstorm",
			"image":"http://openweathermap.org/img/wn/11n@2x.png"
		}
	},
	"96":{
		"day":{
			"description":"Light Thunderstorms With Hail",
			"image":"http://openweathermap.org/img/wn/11d@2x.png"
		},
		"night":{
			"description":"Light Thunderstorms With Hail",
			"image":"http://openweathermap.org/img/wn/11n@2x.png"
		}
	},
	"99":{
		"day":{
			"description":"Thunderstorm With Hail",
			"image":"http://openweathermap.org/img/wn/11d@2x.png"
		},
		"night":{
			"description":"Thunderstorm With Hail",
			"image":"http://openweathermap.org/img/wn/11n@2x.png"
		}
	}
}

# Create a mapping dictionary
mapping_dict = {}
for code, info in json_data.items():
    mapping_dict[int(code)] = info['day']['description']
    
day_weather['weather_code'] = day_weather['weather_code'].map(mapping_dict)
display(day_weather.head())
# Out:
#         date  casual  member  total_rides   weather_code  mean_temp  \
# 0 2021-01-01     371     590          961           Rain        2.3
# 1 2021-01-02    2874    2844         5718     Light Rain        7.6
# 2 2021-01-03     495    1133         1628           Rain        3.9
# 3 2021-01-04     907    2074         2981         Cloudy        4.1
# 4 2021-01-05    1057    2004         3061  Light Drizzle        4.0
#
#    apparent_temp  wind speed
# 0           -0.9        10.6
# 1            4.8        19.1
# 2            0.9        13.0
# 3            1.0        13.3
# 4            1.4         9.2

# %%
display(day_weather['weather_code'].value_counts())
# Out:
# weather_code
# Cloudy           186
# Mainly Sunny     145
# Light Drizzle    130
# Partly Cloudy    102
# Rain              87
# Light Rain        80
# Drizzle           60
# Sunny             51
# Heavy Drizzle     28
# Snow              14
# Heavy Rain        10
# Light Snow         9
# Heavy Snow         9
# Name: count, dtype: int64

# %%
hour_weather['weather_code'] = hour_weather['weather_code'].map(mapping_dict)
display(hour_weather['weather_code'].value_counts())
# Out:
# weather_code
# Sunny            8581
# Mainly Sunny     5057
# Cloudy           3094
# Partly Cloudy    2122
# Light Drizzle    1362
# Drizzle           598
# Light Rain        399
# Rain              222
# Heavy Drizzle     193
# Light Snow        101
# Snow               90
# Heavy Snow         28
# Heavy Rain         17
# Name: count, dtype: int64

# %%
day_weather.rename({'weather_code': 'weather'}, axis='columns', inplace=True)
hour_weather.rename({'weather_code': 'weather'}, axis='columns', inplace=True)

# %%
day_weather.rename({'total_rides': 'rides'}, axis='columns', inplace=True)
hour_weather.rename({'total_rides': 'rides'}, axis='columns', inplace=True)

# %%
day_weather.rename({'wind speed': 'wind_speed'}, axis='columns', inplace=True)

# %%
hour_weather.rename({'wind speed': 'wind_speed'}, axis='columns', inplace=True)

# %%
# List of weather conditions indicating precipitation
precipitation_conditions = ['Light Drizzle', 'Drizzle', 'Heavy Drizzle', 'Light Rain', 'Rain', 'Heavy Rain', 'Light Snow', 'Snow', 'Heavy Snow']

# Create the 'precipitation' column
day_weather['precipitation'] = day_weather['weather'].str.contains('|'.join(precipitation_conditions)).astype(bool)

# %%
hour_weather['precipitation'] = hour_weather['weather'].str.contains('|'.join(precipitation_conditions)).astype(bool)

display(hour_weather.head())
# Out:
#         date  hour  casual  member  total_rides  temp  rel_humid  \
# 0 2021-01-01     0    20.0    26.0         46.0   2.4         90
# 1 2021-01-01     1    23.0    23.0         46.0   1.8         88
# 2 2021-01-01     2    20.0    28.0         48.0   1.1         87
# 3 2021-01-01     3     9.0     7.0         16.0   1.6         81
# 4 2021-01-01     4     7.0     5.0         12.0   1.6         77
#
#          weather  wind speed  precipitation
# 0   Mainly Sunny        10.2          False
# 1   Mainly Sunny        10.0          False
# 2  Partly Cloudy        10.1          False
# 3  Partly Cloudy        10.6          False
# 4  Partly Cloudy         9.9          False

# %%
# Create a 'weekend' column, setting the values to False by default
day_weather['weekend'] = False

# Update the rows corresponding to weekends (1, 2, 8, 9, 15, 16, ...) to True
day_weather.loc[day_weather.index % 7 == 1, 'weekend'] = True
day_weather.loc[day_weather.index % 7 == 2, 'weekend'] = True

# %%
hour_weather['weekend'] = False  # Initialize the 'weekend' column with False
hour_weather.loc[(hour_weather.index % 168 >= 24) & (hour_weather.index % 168 < 72), 'weekend'] = True

# %%
import seaborn as sns

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x='hour', y='rides', data=hour_weather)
# Out:
# <Axes: xlabel='hour', ylabel='rides'>

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x='wind_speed', y='rides', data=day_weather)
# Out:
# <Axes: xlabel='wind_speed', ylabel='rides'>

# %%
def categorize_wind_speed(speed):
    if 0 <= speed < 5:
        return 'still'
    elif 5 <= speed < 10:
        return 'waft'
    elif 10 <= speed < 20:
        return 'breeze'
    elif 20 <= speed < 30:
        return 'blow'
    elif 30 <= speed < 40:
        return 'gust'

hour_weather['wind_speed_category'] = hour_weather['wind_speed'].apply(categorize_wind_speed)

# %%
import matplotlib.pyplot as plt

# Set the size of the figure
plt.figure(figsize=(12, 6))

# Create the lineplot
sns.lineplot(x='hour', y='rides', hue='wind_speed_category', data=hour_weather)

# Set x-axis ticks to display all hours
plt.xticks(range(1, 25))

# Show the plot
plt.show()

# %% [markdown]
# ^ This doesn't really tell us anything, since there were not equal amounts of time at each wind speed, so the number of rides would be different regardless of rider choice based on wind.

# %%
# Group by 'hour' and 'wind_speed_category' and calculate the mean for 'rides'
mean_rides_df = hour_weather.groupby(['hour', 'wind_speed_category'])['rides'].mean().reset_index()
display(mean_rides_df.head(20))

# %%
# Count occurrences
count_df = hour_weather.groupby(['hour', 'wind_speed_category']).count().reset_index()

# Rename the 'rides' column to 'occurrences'
count_df.rename(columns={'rides': 'occurrences'}, inplace=True)

# Merge with mean_rides_df
mean_rides_df = pd.merge(mean_rides_df, count_df[['hour', 'wind_speed_category', 'occurrences']], on=['hour', 'wind_speed_category'])

display(mean_rides_df.head(20))
# Out:
#     hour wind_speed_category       rides  occurrences
# 0      0                blow   76.071429           42
# 1      0              breeze   92.472678          366
# 2      0                gust   41.500000            2
# 3      0               still  108.092308           65
# 4      0                waft  105.862385          436
# 5      1                blow   44.952381           42
# 6      1              breeze   53.879357          373
# 7      1               still   75.646154           65
# 8      1                waft   67.925754          431
# 9      2                blow   28.525000           40
# 10     2              breeze   36.418478          368
# 11     2               still   47.750000           64
# 12     2                waft   41.553531          439
# 13     3                blow   19.613636           44
# 14     3              breeze   20.042735          351
# 15     3               still   24.983051           59
# 16     3                waft   22.426696          457
# 17     4                blow   14.325000           40
# 18     4              breeze   16.767045          352
# 19     4               still   21.131148           61

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

ordered_categories = ['still', 'waft', 'breeze', 'blow', 'gust']

sns.lineplot(x='hour', y='rides', hue='wind_speed_category', data=mean_rides_df, hue_order=ordered_categories)

# Set x-axis ticks to display all hours
plt.xticks(range(1, 25))

# Show the plot
plt.show()

# %% [markdown]
# ^ Now with normalised values. Higher wind speeds make more of a difference outside of peak commuting times. So it appears that leisure rides are more impacted by poor weather than commutes.

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

sns.lineplot(x='hour', y='rides', hue='weekend', data=hour_weather)

# Set x-axis ticks to display all hours
plt.xticks(range(1, 25))

# Show the plot
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

sns.lineplot(x='hour', y='casual', hue='weekend', data=hour_weather)

# Set x-axis ticks to display all hours
plt.xticks(range(1, 25))

# Show the plot
plt.show()

# %% [markdown]
# ^ For casual members, weekend use is higher than weekday use. The weekday peaks for commute times are less accentuated.

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

sns.lineplot(x='hour', y='member', hue='weekend', data=hour_weather)

# Set x-axis ticks to display all hours
plt.xticks(range(1, 25))

# Show the plot
plt.show()

# %% [markdown]
# ^ For regular users, weekday usage is higher and the peaks at commute times are more accentuated.
